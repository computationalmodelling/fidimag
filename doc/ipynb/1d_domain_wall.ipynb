# %% [markdown]
# # 1D domain wall

# %% [markdown]
# **Author**: Marijan Beg
#
# **Date**: 26/02/2016

# %% [markdown]
# ### Problem specification

# %% [markdown]
# The domain wall profile is computed in a one-dimenaional domain of $L=500 \,\text{nm}$ length.
#
# Material paremeters of the simulated material are:
#
# - exchange energy constant $A = 1.3 \times 10^{-11} \,\text{J/m}$,
# - magnetisation saturation $M_\text{s} = 8.6 \times 10^{5} \,\text{A/m}$,
# - anisotropy constant $K_{1} = 1.86 \times 10^{5} \,\text{J/m}^{3}$ with $(1, 0, 0)$ axis,
# - anisotropy constant $K_{2} = -0.92 \times 10^{5} \,\text{J/m}^{3}$ with $(0, 0, 1)$ axis.

# %% [markdown]
# ### Simulation

# %%
from fidimag.micro import Sim
from fidimag.common import CuboidMesh
from fidimag.micro import UniformExchange, UniaxialAnisotropy

# %% [markdown]
# Firstly, the mesh is created.

# %%
# Mesh dimensions.
L = 500  # diameter (nm)

# Mesh discretisation.
dx = dy = dz = 2  # nm

mesh = CuboidMesh(nx=int(L/dx), ny=1, nz=1, dx=dx, dy=dy, dz=dz, unit_length=1e-9)

# %% [markdown]
# The simulation object is created, parameters set, and energies added.

# %%
Ms = 8.6e5  # magnetisation saturation (A/m)
A = 1.3e-11  # exchange energy constant (J/m)
K1 = 1.86e5  # anisotropy energy constant (J/m**3)
u1 = (1, 0, 0)  # anisotropy axis
K2 = -0.92e5  # anisotropy energy constant (J/m**3)
u2 = (0, 0, 1)  # anisotropy axis
alpha = 0.5  # Gilbert damping
gamma = 2.211e5  # gyromagnetic ration (m/As)

# Create simulation object.
sim = Sim(mesh)

# Set simulation parameters.
sim.Ms = Ms
sim.alpha = alpha
sim.gamma = gamma

# Add energies.
sim.add(UniformExchange(A=A))
sim.add(UniaxialAnisotropy(K1, axis=u1))
sim.add(UniaxialAnisotropy(K2, axis=u2))
    
# Since the magnetisation dynamics is not important in this stage,
# the precession term in LLG equation can be set to artificially zero.
sim.do_procession = False

# %% [markdown]
# In order to obtain the domain wall as the relaxed state, the system must be appropriatelly initialised. In this case, the initial magnetisation is set to be in $(0, 0, 1)$ direction for $x < 0.4L \,\text{nm}$, in $(-1, 0, 0)$ direction for $0.4L \,\text{nm} < x < 0.6L \,\text{nm}$, and in $(0, 0, 1)$ direction for $x > 0.6L \,\text{nm}$.

# %%
def m_init(pos):
    x = pos[0]

    if x < 0.4*L:
        return (1,0,0)
    elif x > 0.6*L:
        return (-1,0,0) 
    else:
        return (0,1,0)

# %% [markdown]
# In the next step, the magnetisation is initialised, and the system is relaxed.

# %%
# Initialise the system.
sim.set_m(m_init)

# Relax the system to its equilibrium state.
sim.relax(dt=1e-13, stopping_dmdt=0.01, max_steps=5000, save_m_steps=None, save_vtk_steps=None)
# Out:
# step=1, time=1e-13, max_dmdt=29671.8 ode_step=0
# step=2, time=2e-13, max_dmdt=27922.9 ode_step=1.38626e-14
# step=3, time=3e-13, max_dmdt=26027.9 ode_step=2.5085e-14
# step=4, time=4e-13, max_dmdt=24062.9 ode_step=3.79001e-14
# step=5, time=5e-13, max_dmdt=22093.4 ode_step=3.79001e-14
# step=6, time=6e-13, max_dmdt=20171.6 ode_step=3.79001e-14
# step=7, time=7e-13, max_dmdt=18336.4 ode_step=3.79001e-14
# step=8, time=8e-13, max_dmdt=16613.8 ode_step=3.79001e-14
# step=9, time=9e-13, max_dmdt=15019 ode_step=3.79001e-14
# step=10, time=1e-12, max_dmdt=13558.6 ode_step=3.79001e-14
# step=11, time=1.1e-12, max_dmdt=12233 ode_step=3.79001e-14
# step=12, time=1.2e-12, max_dmdt=11037.9 ode_step=3.79001e-14
# step=13, time=1.3e-12, max_dmdt=9966.16 ode_step=3.79001e-14
# step=14, time=1.4e-12, max_dmdt=9008.82 ode_step=5.68638e-14
# step=15, time=1.5e-12, max_dmdt=8156.2 ode_step=5.68638e-14
# step=16, time=1.6e-12, max_dmdt=7398.4 ode_step=5.68638e-14
# step=17, time=1.7e-12, max_dmdt=6725.78 ode_step=5.68638e-14
# step=18, time=1.8e-12, max_dmdt=6436.63 ode_step=5.68638e-14
# step=19, time=1.9e-12, max_dmdt=6273.62 ode_step=5.68638e-14
# step=20, time=2e-12, max_dmdt=6103.94 ode_step=5.68638e-14
# step=21, time=2.1e-12, max_dmdt=5930.41 ode_step=5.68638e-14
# step=22, time=2.2e-12, max_dmdt=5755.29 ode_step=5.68638e-14
# step=23, time=2.3e-12, max_dmdt=5580.4 ode_step=5.68638e-14
# step=24, time=2.4e-12, max_dmdt=5407.21 ode_step=5.68638e-14
# step=25, time=2.5e-12, max_dmdt=5236.85 ode_step=8.60755e-14
# step=26, time=2.6e-12, max_dmdt=5070.19 ode_step=8.60755e-14
# step=27, time=2.7e-12, max_dmdt=4907.88 ode_step=8.60755e-14
# step=28, time=2.8e-12, max_dmdt=4750.41 ode_step=8.60755e-14
# step=29, time=2.9e-12, max_dmdt=4598.09 ode_step=8.60755e-14
# step=30, time=3e-12, max_dmdt=4451.15 ode_step=8.60755e-14
# step=31, time=3.1e-12, max_dmdt=4309.69 ode_step=8.60755e-14
# step=32, time=3.2e-12, max_dmdt=4173.74 ode_step=8.60755e-14
# step=33, time=3.3e-12, max_dmdt=4043.28 ode_step=8.60755e-14
# step=34, time=3.4e-12, max_dmdt=3918.23 ode_step=8.60755e-14
# step=35, time=3.5e-12, max_dmdt=3798.47 ode_step=8.60755e-14
# step=36, time=3.6e-12, max_dmdt=3683.87 ode_step=8.60755e-14
# step=37, time=3.7e-12, max_dmdt=3574.27 ode_step=8.60755e-14
# step=38, time=3.8e-12, max_dmdt=3469.49 ode_step=8.60755e-14
# step=39, time=3.9e-12, max_dmdt=3369.34 ode_step=8.60755e-14
# step=40, time=4e-12, max_dmdt=3273.65 ode_step=8.60755e-14
# step=41, time=4.1e-12, max_dmdt=3182.21 ode_step=8.60755e-14
# step=42, time=4.23115e-12, max_dmdt=3081.69 ode_step=1.31154e-13
# step=43, time=4.36231e-12, max_dmdt=2973.7 ode_step=1.31154e-13
# step=44, time=4.49346e-12, max_dmdt=2871.93 ode_step=1.31154e-13
# step=45, time=4.62462e-12, max_dmdt=2802.18 ode_step=1.31154e-13
# step=46, time=4.75577e-12, max_dmdt=2756.08 ode_step=1.31154e-13
# step=47, time=4.88692e-12, max_dmdt=2710.23 ode_step=1.31154e-13
# step=48, time=5.01808e-12, max_dmdt=2664.8 ode_step=1.31154e-13
# step=49, time=5.14923e-12, max_dmdt=2619.91 ode_step=1.31154e-13
# step=50, time=5.28039e-12, max_dmdt=2575.65 ode_step=1.31154e-13
# step=51, time=5.41154e-12, max_dmdt=2532.11 ode_step=1.31154e-13
# step=52, time=5.54269e-12, max_dmdt=2489.35 ode_step=1.31154e-13
# step=53, time=5.67385e-12, max_dmdt=2447.42 ode_step=1.31154e-13
# step=54, time=5.805e-12, max_dmdt=2406.37 ode_step=1.31154e-13
# step=55, time=5.93616e-12, max_dmdt=2366.2 ode_step=1.31154e-13
# step=56, time=6.06731e-12, max_dmdt=2326.94 ode_step=1.31154e-13
# step=57, time=6.19846e-12, max_dmdt=2288.61 ode_step=1.31154e-13
# step=58, time=6.32962e-12, max_dmdt=2251.2 ode_step=1.31154e-13
# step=59, time=6.46077e-12, max_dmdt=2214.71 ode_step=1.31154e-13
# step=60, time=6.65972e-12, max_dmdt=2170.14 ode_step=1.98949e-13
# step=61, time=6.85867e-12, max_dmdt=2118.26 ode_step=1.98949e-13
# step=62, time=7.05762e-12, max_dmdt=2068.41 ode_step=1.98949e-13
# step=63, time=7.25657e-12, max_dmdt=2020.53 ode_step=1.98949e-13
# step=64, time=7.45552e-12, max_dmdt=1974.57 ode_step=1.98949e-13
# step=65, time=7.65446e-12, max_dmdt=1930.44 ode_step=1.98949e-13
# step=66, time=7.85341e-12, max_dmdt=1888.09 ode_step=1.98949e-13
# step=67, time=8.05236e-12, max_dmdt=1847.43 ode_step=1.98949e-13
# step=68, time=8.25131e-12, max_dmdt=1808.39 ode_step=1.98949e-13
# step=69, time=8.45026e-12, max_dmdt=1770.9 ode_step=1.98949e-13
# step=70, time=8.64921e-12, max_dmdt=1734.9 ode_step=1.98949e-13
# step=71, time=8.84816e-12, max_dmdt=1700.3 ode_step=1.98949e-13
# step=72, time=9.04711e-12, max_dmdt=1667.05 ode_step=1.98949e-13
# step=73, time=9.24606e-12, max_dmdt=1635.09 ode_step=1.98949e-13
# step=74, time=9.445e-12, max_dmdt=1613.8 ode_step=1.98949e-13
# step=75, time=9.64395e-12, max_dmdt=1595.7 ode_step=1.98949e-13
# step=76, time=9.8429e-12, max_dmdt=1577.85 ode_step=1.98949e-13
# step=77, time=1.00419e-11, max_dmdt=1560.25 ode_step=1.98949e-13
# step=78, time=1.02408e-11, max_dmdt=1542.93 ode_step=1.98949e-13
# step=79, time=1.04397e-11, max_dmdt=1525.88 ode_step=1.98949e-13
# step=80, time=1.07392e-11, max_dmdt=1504.94 ode_step=2.99476e-13
# step=81, time=1.10387e-11, max_dmdt=1480.36 ode_step=2.99476e-13
# step=82, time=1.13382e-11, max_dmdt=1456.45 ode_step=2.99476e-13
# step=83, time=1.16377e-11, max_dmdt=1433.2 ode_step=2.99476e-13
# step=84, time=1.19371e-11, max_dmdt=1410.61 ode_step=2.99476e-13
# step=85, time=1.22366e-11, max_dmdt=1388.67 ode_step=2.99476e-13
# step=86, time=1.25361e-11, max_dmdt=1367.37 ode_step=2.99476e-13
# step=87, time=1.28356e-11, max_dmdt=1346.69 ode_step=2.99476e-13
# step=88, time=1.3135e-11, max_dmdt=1326.62 ode_step=2.99476e-13
# step=89, time=1.34345e-11, max_dmdt=1307.14 ode_step=2.99476e-13
# step=90, time=1.3734e-11, max_dmdt=1288.22 ode_step=2.99476e-13
# step=91, time=1.40335e-11, max_dmdt=1269.86 ode_step=2.99476e-13
# step=92, time=1.43329e-11, max_dmdt=1252.04 ode_step=2.99476e-13
# step=93, time=1.46324e-11, max_dmdt=1234.72 ode_step=2.99476e-13
# step=94, time=1.49319e-11, max_dmdt=1217.9 ode_step=2.99476e-13
# step=95, time=1.52314e-11, max_dmdt=1201.56 ode_step=2.99476e-13
# step=96, time=1.55308e-11, max_dmdt=1185.67 ode_step=2.99476e-13
# step=97, time=1.58303e-11, max_dmdt=1171.94 ode_step=2.99476e-13
# step=98, time=1.61298e-11, max_dmdt=1162.97 ode_step=2.99476e-13
# step=99, time=1.64293e-11, max_dmdt=1154.07 ode_step=2.99476e-13
# step=100, time=1.67287e-11, max_dmdt=1145.24 ode_step=2.99476e-13
# step=101, time=1.70282e-11, max_dmdt=1136.49 ode_step=2.99476e-13
# step=102, time=1.74879e-11, max_dmdt=1125.52 ode_step=4.59706e-13
# step=103, time=1.79476e-11, max_dmdt=1112.42 ode_step=4.59706e-13
# step=104, time=1.84073e-11, max_dmdt=1099.52 ode_step=4.59706e-13
# step=105, time=1.8867e-11, max_dmdt=1086.83 ode_step=4.59706e-13
# step=106, time=1.93267e-11, max_dmdt=1074.36 ode_step=4.59706e-13
# step=107, time=1.97865e-11, max_dmdt=1062.1 ode_step=4.59706e-13
# step=108, time=2.02462e-11, max_dmdt=1050.04 ode_step=4.59706e-13
# step=109, time=2.07059e-11, max_dmdt=1038.19 ode_step=4.59706e-13
# step=110, time=2.11656e-11, max_dmdt=1026.54 ode_step=4.59706e-13
# step=111, time=2.16253e-11, max_dmdt=1015.08 ode_step=4.59706e-13
# step=112, time=2.2085e-11, max_dmdt=1003.81 ode_step=4.59706e-13
# step=113, time=2.25447e-11, max_dmdt=992.72 ode_step=4.59706e-13
# step=114, time=2.30044e-11, max_dmdt=981.96 ode_step=4.59706e-13
# step=115, time=2.34641e-11, max_dmdt=976.393 ode_step=4.59706e-13
# step=116, time=2.39238e-11, max_dmdt=970.747 ode_step=4.59706e-13
# step=117, time=2.4632e-11, max_dmdt=963.468 ode_step=7.08226e-13
# step=118, time=2.53403e-11, max_dmdt=954.506 ode_step=7.08226e-13
# step=119, time=2.60485e-11, max_dmdt=945.409 ode_step=7.08226e-13
# step=120, time=2.67567e-11, max_dmdt=936.19 ode_step=7.08226e-13
# step=121, time=2.74649e-11, max_dmdt=926.86 ode_step=7.08226e-13
# step=122, time=2.81732e-11, max_dmdt=917.43 ode_step=7.08226e-13
# step=123, time=2.88814e-11, max_dmdt=907.906 ode_step=7.08226e-13
# step=124, time=2.95896e-11, max_dmdt=898.295 ode_step=7.08226e-13
# step=125, time=3.02978e-11, max_dmdt=888.933 ode_step=7.08226e-13
# step=126, time=3.10061e-11, max_dmdt=884.906 ode_step=7.08226e-13
# step=127, time=3.17143e-11, max_dmdt=880.549 ode_step=7.08226e-13
# step=128, time=3.24225e-11, max_dmdt=875.876 ode_step=7.08226e-13
# step=129, time=3.31308e-11, max_dmdt=870.898 ode_step=7.08226e-13
# step=130, time=3.3839e-11, max_dmdt=865.626 ode_step=7.08226e-13
# step=131, time=3.45472e-11, max_dmdt=860.072 ode_step=7.08226e-13
# step=132, time=3.52554e-11, max_dmdt=854.245 ode_step=7.08226e-13
# step=133, time=3.59637e-11, max_dmdt=848.155 ode_step=7.08226e-13
# step=134, time=3.66719e-11, max_dmdt=841.811 ode_step=7.08226e-13
# step=135, time=3.73801e-11, max_dmdt=837.103 ode_step=7.08226e-13
# step=136, time=3.80883e-11, max_dmdt=834.999 ode_step=7.08226e-13
# step=137, time=3.87966e-11, max_dmdt=832.519 ode_step=7.08226e-13
# step=138, time=3.95048e-11, max_dmdt=829.672 ode_step=7.08226e-13
# step=139, time=4.07882e-11, max_dmdt=825.031 ode_step=1.28339e-12
# step=140, time=4.20716e-11, max_dmdt=818.085 ode_step=1.28339e-12
# step=141, time=4.3355e-11, max_dmdt=810.052 ode_step=1.28339e-12
# step=142, time=4.46384e-11, max_dmdt=805.3 ode_step=1.28339e-12
# step=143, time=4.59218e-11, max_dmdt=802.66 ode_step=1.28339e-12
# step=144, time=4.72051e-11, max_dmdt=798.752 ode_step=1.28339e-12
# step=145, time=4.84885e-11, max_dmdt=793.614 ode_step=1.28339e-12
# step=146, time=4.97719e-11, max_dmdt=787.29 ode_step=1.28339e-12
# step=147, time=5.10553e-11, max_dmdt=784.768 ode_step=1.28339e-12
# step=148, time=5.23387e-11, max_dmdt=783.032 ode_step=1.28339e-12
# step=149, time=5.36221e-11, max_dmdt=779.998 ode_step=1.28339e-12
# step=150, time=5.49055e-11, max_dmdt=775.696 ode_step=1.28339e-12
# step=151, time=5.61889e-11, max_dmdt=770.36 ode_step=1.28339e-12
# step=152, time=5.74723e-11, max_dmdt=770.199 ode_step=1.28339e-12
# step=153, time=5.87557e-11, max_dmdt=768.704 ode_step=1.28339e-12
# step=154, time=6.00391e-11, max_dmdt=765.899 ode_step=1.28339e-12
# step=155, time=6.13225e-11, max_dmdt=761.812 ode_step=1.28339e-12
# step=156, time=6.26059e-11, max_dmdt=759.649 ode_step=1.28339e-12
# step=157, time=6.38893e-11, max_dmdt=759.275 ode_step=1.28339e-12
# step=158, time=6.51726e-11, max_dmdt=757.565 ode_step=1.28339e-12
# step=159, time=6.6456e-11, max_dmdt=754.54 ode_step=1.28339e-12
# step=160, time=6.77394e-11, max_dmdt=750.794 ode_step=1.28339e-12
# step=161, time=6.90228e-11, max_dmdt=751.199 ode_step=1.28339e-12
# step=162, time=7.03062e-11, max_dmdt=750.253 ode_step=1.28339e-12
# step=163, time=7.15896e-11, max_dmdt=747.969 ode_step=1.28339e-12
# step=164, time=7.2873e-11, max_dmdt=744.371 ode_step=1.28339e-12
# step=165, time=7.41564e-11, max_dmdt=743.779 ode_step=1.28339e-12
# step=166, time=7.54398e-11, max_dmdt=743.293 ode_step=1.28339e-12
# step=167, time=7.67232e-11, max_dmdt=741.452 ode_step=1.28339e-12
# step=168, time=7.80066e-11, max_dmdt=738.275 ode_step=1.28339e-12
# step=169, time=7.929e-11, max_dmdt=735.945 ode_step=1.28339e-12
# step=170, time=8.05734e-11, max_dmdt=735.617 ode_step=1.28339e-12
# step=171, time=8.18568e-11, max_dmdt=733.921 ode_step=1.28339e-12
# step=172, time=8.31401e-11, max_dmdt=730.873 ode_step=1.28339e-12
# step=173, time=8.44235e-11, max_dmdt=726.498 ode_step=1.28339e-12
# step=174, time=8.57069e-11, max_dmdt=725.589 ode_step=1.28339e-12
# step=175, time=8.69903e-11, max_dmdt=723.736 ode_step=1.28339e-12
# step=176, time=8.82737e-11, max_dmdt=720.528 ode_step=1.28339e-12
# step=177, time=8.95571e-11, max_dmdt=715.99 ode_step=1.28339e-12
# step=178, time=9.08405e-11, max_dmdt=710.909 ode_step=1.28339e-12
# step=179, time=9.21239e-11, max_dmdt=708.617 ode_step=1.28339e-12
# step=180, time=9.34073e-11, max_dmdt=704.988 ode_step=1.28339e-12
# step=181, time=9.46907e-11, max_dmdt=700.054 ode_step=1.28339e-12
# step=182, time=9.59741e-11, max_dmdt=693.852 ode_step=1.28339e-12
# step=183, time=9.72575e-11, max_dmdt=686.432 ode_step=1.28339e-12
# step=184, time=9.85409e-11, max_dmdt=681.461 ode_step=1.28339e-12
# step=185, time=9.98243e-11, max_dmdt=675.986 ode_step=1.28339e-12
# step=186, time=1.01108e-10, max_dmdt=669.308 ode_step=1.28339e-12
# step=187, time=1.02391e-10, max_dmdt=661.48 ode_step=1.28339e-12
# step=188, time=1.03674e-10, max_dmdt=652.563 ode_step=1.28339e-12
# step=189, time=1.04958e-10, max_dmdt=642.622 ode_step=1.28339e-12
# step=190, time=1.06241e-10, max_dmdt=633.67 ode_step=1.28339e-12
# step=191, time=1.07525e-10, max_dmdt=625.525 ode_step=1.28339e-12
# step=192, time=1.08808e-10, max_dmdt=616.405 ode_step=1.28339e-12
# step=193, time=1.10091e-10, max_dmdt=606.377 ode_step=1.28339e-12
# step=194, time=1.11375e-10, max_dmdt=595.513 ode_step=1.28339e-12
# step=195, time=1.12658e-10, max_dmdt=583.887 ode_step=1.28339e-12
# step=196, time=1.13942e-10, max_dmdt=571.577 ode_step=1.28339e-12
# step=197, time=1.15225e-10, max_dmdt=558.662 ode_step=1.28339e-12
# step=198, time=1.16508e-10, max_dmdt=546.48 ode_step=1.28339e-12
# step=199, time=1.17792e-10, max_dmdt=535.378 ode_step=1.28339e-12
# step=200, time=1.19075e-10, max_dmdt=523.724 ode_step=1.28339e-12
# step=201, time=1.20359e-10, max_dmdt=513.919 ode_step=1.28339e-12
# step=202, time=1.21642e-10, max_dmdt=507.292 ode_step=1.28339e-12
# step=203, time=1.22925e-10, max_dmdt=500.108 ode_step=1.28339e-12
# step=204, time=1.24209e-10, max_dmdt=492.417 ode_step=1.28339e-12
# step=205, time=1.25492e-10, max_dmdt=484.27 ode_step=1.28339e-12
# step=206, time=1.26776e-10, max_dmdt=475.716 ode_step=1.28339e-12
# step=207, time=1.28059e-10, max_dmdt=466.804 ode_step=1.28339e-12
# step=208, time=1.29342e-10, max_dmdt=457.579 ode_step=1.28339e-12
# step=209, time=1.30626e-10, max_dmdt=448.356 ode_step=1.28339e-12
# step=210, time=1.31909e-10, max_dmdt=439.634 ode_step=1.28339e-12
# step=211, time=1.33192e-10, max_dmdt=430.62 ode_step=1.28339e-12
# step=212, time=1.34476e-10, max_dmdt=421.357 ode_step=1.28339e-12
# step=213, time=1.35759e-10, max_dmdt=411.888 ode_step=1.28339e-12
# step=214, time=1.37043e-10, max_dmdt=402.253 ode_step=1.28339e-12
# step=215, time=1.38326e-10, max_dmdt=392.491 ode_step=1.28339e-12
# step=216, time=1.39609e-10, max_dmdt=382.637 ode_step=1.28339e-12
# step=217, time=1.40893e-10, max_dmdt=372.725 ode_step=1.28339e-12
# step=218, time=1.42176e-10, max_dmdt=362.785 ode_step=1.28339e-12
# step=219, time=1.44113e-10, max_dmdt=350.321 ode_step=1.93684e-12
# step=220, time=1.4605e-10, max_dmdt=335.403 ode_step=1.93684e-12
# step=221, time=1.47987e-10, max_dmdt=320.641 ode_step=1.93684e-12
# step=222, time=1.49924e-10, max_dmdt=306.103 ode_step=1.93684e-12
# step=223, time=1.5186e-10, max_dmdt=291.847 ode_step=1.93684e-12
# step=224, time=1.53797e-10, max_dmdt=277.922 ode_step=1.93684e-12
# step=225, time=1.55734e-10, max_dmdt=264.366 ode_step=1.93684e-12
# step=226, time=1.57671e-10, max_dmdt=251.211 ode_step=1.93684e-12
# step=227, time=1.59608e-10, max_dmdt=238.481 ode_step=1.93684e-12
# step=228, time=1.61545e-10, max_dmdt=226.196 ode_step=1.93684e-12
# step=229, time=1.63482e-10, max_dmdt=214.366 ode_step=1.93684e-12
# step=230, time=1.65418e-10, max_dmdt=203 ode_step=1.93684e-12
# step=231, time=1.67355e-10, max_dmdt=192.101 ode_step=1.93684e-12
# step=232, time=1.69292e-10, max_dmdt=181.667 ode_step=1.93684e-12
# step=233, time=1.71229e-10, max_dmdt=171.696 ode_step=1.93684e-12
# step=234, time=1.73166e-10, max_dmdt=162.182 ode_step=1.93684e-12
# step=235, time=1.75103e-10, max_dmdt=153.115 ode_step=1.93684e-12
# step=236, time=1.77039e-10, max_dmdt=144.486 ode_step=1.93684e-12
# step=237, time=1.78976e-10, max_dmdt=136.283 ode_step=1.93684e-12
# step=238, time=1.80913e-10, max_dmdt=128.493 ode_step=1.93684e-12
# step=239, time=1.8285e-10, max_dmdt=121.103 ode_step=1.93684e-12
# step=240, time=1.84787e-10, max_dmdt=114.098 ode_step=1.93684e-12
# step=241, time=1.86724e-10, max_dmdt=107.464 ode_step=1.93684e-12
# step=242, time=1.88661e-10, max_dmdt=101.185 ode_step=1.93684e-12
# step=243, time=1.90597e-10, max_dmdt=95.2482 ode_step=1.93684e-12
# step=244, time=1.92534e-10, max_dmdt=89.637 ode_step=1.93684e-12
# step=245, time=1.94471e-10, max_dmdt=84.3371 ode_step=1.93684e-12
# step=246, time=1.96408e-10, max_dmdt=79.3338 ode_step=1.93684e-12
# step=247, time=1.98345e-10, max_dmdt=74.6131 ode_step=1.93684e-12
# step=248, time=2.00282e-10, max_dmdt=70.1609 ode_step=1.93684e-12
# step=249, time=2.02218e-10, max_dmdt=65.9638 ode_step=1.93684e-12
# step=250, time=2.04155e-10, max_dmdt=62.0086 ode_step=1.93684e-12
# step=251, time=2.06092e-10, max_dmdt=58.2828 ode_step=1.93684e-12
# step=252, time=2.09322e-10, max_dmdt=53.6646 ode_step=3.22956e-12
# step=253, time=2.12551e-10, max_dmdt=48.3727 ode_step=3.22956e-12
# step=254, time=2.15781e-10, max_dmdt=43.5916 ode_step=3.22956e-12
# step=255, time=2.1901e-10, max_dmdt=39.2748 ode_step=3.22956e-12
# step=256, time=2.2224e-10, max_dmdt=35.3793 ode_step=3.22956e-12
# step=257, time=2.25469e-10, max_dmdt=31.8656 ode_step=3.22956e-12
# step=258, time=2.28699e-10, max_dmdt=28.6977 ode_step=3.22956e-12
# step=259, time=2.31929e-10, max_dmdt=25.8423 ode_step=3.22956e-12
# step=260, time=2.35158e-10, max_dmdt=23.2694 ode_step=3.22956e-12
# step=261, time=2.38388e-10, max_dmdt=20.9517 ode_step=3.22956e-12
# step=262, time=2.41617e-10, max_dmdt=18.8642 ode_step=3.22956e-12
# step=263, time=2.44847e-10, max_dmdt=16.9843 ode_step=3.22956e-12
# step=264, time=2.48076e-10, max_dmdt=15.2917 ode_step=3.22956e-12
# step=265, time=2.51306e-10, max_dmdt=13.7679 ode_step=3.22956e-12
# step=266, time=2.54536e-10, max_dmdt=12.3961 ode_step=3.22956e-12
# step=267, time=2.57765e-10, max_dmdt=11.1612 ode_step=3.22956e-12
# step=268, time=2.60995e-10, max_dmdt=10.0496 ode_step=3.22956e-12
# step=269, time=2.64224e-10, max_dmdt=9.04906 ode_step=3.22956e-12
# step=270, time=2.67454e-10, max_dmdt=8.14847 ode_step=3.22956e-12
# step=271, time=2.70683e-10, max_dmdt=7.33784 ode_step=3.22956e-12
# step=272, time=2.73913e-10, max_dmdt=6.60818 ode_step=3.22956e-12
# step=273, time=2.77143e-10, max_dmdt=5.95139 ode_step=3.22956e-12
# step=274, time=2.80372e-10, max_dmdt=5.36017 ode_step=3.22956e-12
# step=275, time=2.83602e-10, max_dmdt=4.82796 ode_step=3.22956e-12
# step=276, time=2.86831e-10, max_dmdt=4.34884 ode_step=3.22956e-12
# step=277, time=2.90061e-10, max_dmdt=3.91752 ode_step=3.22956e-12
# step=278, time=2.9329e-10, max_dmdt=3.52918 ode_step=3.22956e-12
# step=279, time=2.9652e-10, max_dmdt=3.18064 ode_step=3.22956e-12
# step=280, time=2.99749e-10, max_dmdt=2.8668 ode_step=3.22956e-12
# step=281, time=3.02979e-10, max_dmdt=2.58405 ode_step=3.22956e-12
# step=282, time=3.06209e-10, max_dmdt=2.32931 ode_step=3.22956e-12
# step=283, time=3.09438e-10, max_dmdt=2.0998 ode_step=3.22956e-12
# step=284, time=3.12668e-10, max_dmdt=1.89299 ode_step=3.22956e-12
# step=285, time=3.15897e-10, max_dmdt=1.70664 ode_step=3.22956e-12
# step=286, time=3.19127e-10, max_dmdt=1.53871 ode_step=3.22956e-12
# step=287, time=3.22356e-10, max_dmdt=1.38738 ode_step=3.22956e-12
# step=288, time=3.25586e-10, max_dmdt=1.25099 ode_step=3.22956e-12
# step=289, time=3.28816e-10, max_dmdt=1.12807 ode_step=3.22956e-12
# step=290, time=3.32045e-10, max_dmdt=1.01729 ode_step=3.22956e-12
# step=291, time=3.35275e-10, max_dmdt=0.917421 ode_step=3.22956e-12
# step=292, time=3.38504e-10, max_dmdt=0.827402 ode_step=3.22956e-12
# step=293, time=3.41734e-10, max_dmdt=0.746254 ode_step=3.22956e-12
# step=294, time=3.44963e-10, max_dmdt=0.673096 ode_step=3.22956e-12
# step=295, time=3.48193e-10, max_dmdt=0.607139 ode_step=3.22956e-12
# step=296, time=3.51422e-10, max_dmdt=0.547673 ode_step=3.22956e-12
# step=297, time=3.54652e-10, max_dmdt=0.494055 ode_step=3.22956e-12
# step=298, time=3.57882e-10, max_dmdt=0.445703 ode_step=3.22956e-12
# step=299, time=3.62911e-10, max_dmdt=0.390977 ode_step=5.02951e-12
# step=300, time=3.67941e-10, max_dmdt=0.333093 ode_step=5.02951e-12
# step=301, time=3.7297e-10, max_dmdt=0.283813 ode_step=5.02951e-12
# step=302, time=3.78e-10, max_dmdt=0.241854 ode_step=5.02951e-12
# step=303, time=3.83029e-10, max_dmdt=0.20612 ode_step=5.02951e-12
# step=304, time=3.88059e-10, max_dmdt=0.175681 ode_step=5.02951e-12
# step=305, time=3.93088e-10, max_dmdt=0.149749 ode_step=5.02951e-12
# step=306, time=3.98118e-10, max_dmdt=0.127658 ode_step=5.02951e-12
# step=307, time=4.03147e-10, max_dmdt=0.108837 ode_step=5.02951e-12
# step=308, time=4.08177e-10, max_dmdt=0.0927988 ode_step=5.02951e-12
# step=309, time=4.13206e-10, max_dmdt=0.0791305 ode_step=5.02951e-12
# step=310, time=4.18236e-10, max_dmdt=0.0674812 ode_step=5.02951e-12
# step=311, time=4.23265e-10, max_dmdt=0.0575518 ode_step=5.02951e-12
# step=312, time=4.28295e-10, max_dmdt=0.0490871 ode_step=5.02951e-12
# step=313, time=4.33324e-10, max_dmdt=0.0418708 ode_step=5.02951e-12
# step=314, time=4.38354e-10, max_dmdt=0.0357182 ode_step=5.02951e-12
# step=315, time=4.43383e-10, max_dmdt=0.0304723 ode_step=5.02951e-12
# step=316, time=4.48413e-10, max_dmdt=0.0259988 ode_step=5.02951e-12
# step=317, time=4.53442e-10, max_dmdt=0.0221837 ode_step=5.02951e-12
# step=318, time=4.58472e-10, max_dmdt=0.0189291 ode_step=5.02951e-12
# step=319, time=4.66078e-10, max_dmdt=0.0155301 ode_step=7.60624e-12
# step=320, time=4.73684e-10, max_dmdt=0.0122183 ode_step=7.60624e-12
# step=321, time=4.81291e-10, max_dmdt=0.00961507 ode_step=7.60624e-12

# %% [markdown]
# After the system is relaxed, the magnetisation profile can be plotted.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

m = sim.spin

mx = m[:, 0]
my = m[:, 1]
mz = m[:, 2]

x_array = np.arange(0, L, dx)

plt.figure(figsize=(10,6))
plt.plot(x_array, mx, label='mx')
plt.plot(x_array, my, label='my')
plt.plot(x_array, mz, label='mz')
plt.xlabel('x (nm)')
plt.ylabel('<m>')
plt.xlim([0.4*L, 0.6*L])
plt.ylim([-1, 1])
plt.grid()
plt.legend()
