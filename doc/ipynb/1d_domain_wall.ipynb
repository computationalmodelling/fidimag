# %% [markdown]
# # 1D domain wall

# %% [markdown]
# **Author**: Marijan Beg
#
# **Date**: 26/02/2016

# %% [markdown]
# ### Problem specification

# %% [markdown]
# The domain wall profile is computed in a one-dimenaional domain of $L=500 \,\text{nm}$ length.
#
# Material paremeters of the simulated material are:
#
# - exchange energy constant $A = 1.3 \times 10^{-11} \,\text{J/m}$,
# - magnetisation saturation $M_\text{s} = 8.6 \times 10^{5} \,\text{A/m}$,
# - anisotropy constant $K_{1} = 1.86 \times 10^{5} \,\text{J/m}^{3}$ with $(1, 0, 0)$ axis,
# - anisotropy constant $K_{2} = -0.92 \times 10^{5} \,\text{J/m}^{3}$ with $(0, 0, 1)$ axis.

# %% [markdown]
# ### Simulation

# %%
from fidimag.micro import Sim
from fidimag.common import CuboidMesh
from fidimag.micro import UniformExchange, UniaxialAnisotropy

# %% [markdown]
# Firstly, the mesh is created.

# %%
# Mesh dimensions.
L = 500  # diameter (nm)

# Mesh discretisation.
dx = dy = dz = 2  # nm

mesh = CuboidMesh(nx=int(L/dx), ny=1, nz=1, dx=dx, dy=dy, dz=dz, unit_length=1e-9)

# %% [markdown]
# The simulation object is created, parameters set, and energies added.

# %%
Ms = 8.6e5  # magnetisation saturation (A/m)
A = 1.3e-11  # exchange energy constant (J/m)
K1 = 1.86e5  # anisotropy energy constant (J/m**3)
u1 = (1, 0, 0)  # anisotropy axis
K2 = -0.92e5  # anisotropy energy constant (J/m**3)
u2 = (0, 0, 1)  # anisotropy axis
alpha = 0.5  # Gilbert damping
gamma = 2.211e5  # gyromagnetic ration (m/As)

# Create simulation object.
sim = Sim(mesh)

# Set simulation parameters.
sim.Ms = Ms
sim.alpha = alpha
sim.gamma = gamma

# Add energies.
sim.add(UniformExchange(A=A))
sim.add(UniaxialAnisotropy(K1, axis=u1))
sim.add(UniaxialAnisotropy(K2, axis=u2))
    
# Since the magnetisation dynamics is not important in this stage,
# the precession term in LLG equation can be set to artificially zero.
sim.do_procession = False

# %% [markdown]
# In order to obtain the domain wall as the relaxed state, the system must be appropriatelly initialised. In this case, the initial magnetisation is set to be in $(0, 0, 1)$ direction for $x < 0.4L \,\text{nm}$, in $(-1, 0, 0)$ direction for $0.4L \,\text{nm} < x < 0.6L \,\text{nm}$, and in $(0, 0, 1)$ direction for $x > 0.6L \,\text{nm}$.

# %%
def m_init(pos):
    x = pos[0]

    if x < 0.4*L:
        return (1,0,0)
    elif x > 0.6*L:
        return (-1,0,0) 
    else:
        return (0,1,0)

# %% [markdown]
# In the next step, the magnetisation is initialised, and the system is relaxed.

# %%
# Initialise the system.
sim.set_m(m_init)

# Relax the system to its equilibrium state.
sim.relax(dt=1e-13, stopping_dmdt=0.01, max_steps=5000, save_m_steps=None, save_vtk_steps=None)
# Out:
# step=1, time=1e-13, max_dmdt=55682.2 ode_step=0
# step=2, time=2e-13, max_dmdt=43729.1 ode_step=1.64532e-14
# step=3, time=3e-13, max_dmdt=46809.7 ode_step=1.64532e-14
# step=4, time=4e-13, max_dmdt=46477.2 ode_step=2.72984e-14
# step=5, time=5e-13, max_dmdt=42995.5 ode_step=2.72984e-14
# step=6, time=6e-13, max_dmdt=37284.8 ode_step=2.72984e-14
# step=7, time=7e-13, max_dmdt=30384 ode_step=2.72984e-14
# step=8, time=8e-13, max_dmdt=23262 ode_step=2.72984e-14
# step=9, time=9e-13, max_dmdt=21165.1 ode_step=2.72984e-14
# step=10, time=1e-12, max_dmdt=21898.8 ode_step=2.72984e-14
# step=11, time=1.1e-12, max_dmdt=21633.8 ode_step=2.72984e-14
# step=12, time=1.2e-12, max_dmdt=20558.3 ode_step=2.72984e-14
# step=13, time=1.3e-12, max_dmdt=18819.2 ode_step=2.72984e-14
# step=14, time=1.4e-12, max_dmdt=16701.6 ode_step=2.72984e-14
# step=15, time=1.5e-12, max_dmdt=14465.5 ode_step=2.72984e-14
# step=16, time=1.6e-12, max_dmdt=12417.8 ode_step=2.72984e-14
# step=17, time=1.7e-12, max_dmdt=12564.1 ode_step=2.72984e-14
# step=18, time=1.8e-12, max_dmdt=12307.3 ode_step=2.72984e-14
# step=19, time=1.9e-12, max_dmdt=11919.3 ode_step=4.10636e-14
# step=20, time=2e-12, max_dmdt=11354.2 ode_step=4.10636e-14
# step=21, time=2.1e-12, max_dmdt=10654.5 ode_step=4.10636e-14
# step=22, time=2.2e-12, max_dmdt=9899.94 ode_step=4.10636e-14
# step=23, time=2.3e-12, max_dmdt=9152.89 ode_step=4.10636e-14
# step=24, time=2.4e-12, max_dmdt=8456.45 ode_step=4.10636e-14
# step=25, time=2.5e-12, max_dmdt=7835.36 ode_step=4.10636e-14
# step=26, time=2.6e-12, max_dmdt=7405.17 ode_step=4.10636e-14
# step=27, time=2.7e-12, max_dmdt=7184.29 ode_step=4.10636e-14
# step=28, time=2.8e-12, max_dmdt=6914.21 ode_step=4.10636e-14
# step=29, time=2.9e-12, max_dmdt=6703.49 ode_step=4.10636e-14
# step=30, time=3e-12, max_dmdt=6499.58 ode_step=4.10636e-14
# step=31, time=3.1e-12, max_dmdt=6292.4 ode_step=4.10636e-14
# step=32, time=3.2e-12, max_dmdt=6091.61 ode_step=4.10636e-14
# step=33, time=3.3e-12, max_dmdt=5902.39 ode_step=4.10636e-14
# step=34, time=3.4e-12, max_dmdt=5726.54 ode_step=6.1936e-14
# step=35, time=3.5e-12, max_dmdt=5563.61 ode_step=6.1936e-14
# step=36, time=3.6e-12, max_dmdt=5411.97 ode_step=6.1936e-14
# step=37, time=3.7e-12, max_dmdt=5269.5 ode_step=6.1936e-14
# step=38, time=3.8e-12, max_dmdt=5134.19 ode_step=6.1936e-14
# step=39, time=3.9e-12, max_dmdt=5004.38 ode_step=6.1936e-14
# step=40, time=4e-12, max_dmdt=4878.93 ode_step=6.1936e-14
# step=41, time=4.1e-12, max_dmdt=4757.2 ode_step=6.1936e-14
# step=42, time=4.2e-12, max_dmdt=4638.94 ode_step=6.1936e-14
# step=43, time=4.3e-12, max_dmdt=4524.17 ode_step=6.1936e-14
# step=44, time=4.4e-12, max_dmdt=4413.09 ode_step=6.1936e-14
# step=45, time=4.5e-12, max_dmdt=4305.91 ode_step=6.1936e-14
# step=46, time=4.6e-12, max_dmdt=4202.81 ode_step=6.1936e-14
# step=47, time=4.7e-12, max_dmdt=4103.88 ode_step=6.1936e-14
# step=48, time=4.8e-12, max_dmdt=4009.14 ode_step=6.1936e-14
# step=49, time=4.9e-12, max_dmdt=3918.5 ode_step=6.1936e-14
# step=50, time=5e-12, max_dmdt=3856.84 ode_step=6.1936e-14
# step=51, time=5.1e-12, max_dmdt=3808.64 ode_step=9.43137e-14
# step=52, time=5.2e-12, max_dmdt=3760.05 ode_step=9.43137e-14
# step=53, time=5.3e-12, max_dmdt=3711.4 ode_step=9.43137e-14
# step=54, time=5.4e-12, max_dmdt=3662.91 ode_step=9.43137e-14
# step=55, time=5.5e-12, max_dmdt=3614.8 ode_step=9.43137e-14
# step=56, time=5.6e-12, max_dmdt=3567.2 ode_step=9.43137e-14
# step=57, time=5.7e-12, max_dmdt=3520.21 ode_step=9.43137e-14
# step=58, time=5.8e-12, max_dmdt=3473.93 ode_step=9.43137e-14
# step=59, time=5.9e-12, max_dmdt=3428.41 ode_step=9.43137e-14
# step=60, time=6e-12, max_dmdt=3383.67 ode_step=9.43137e-14
# step=61, time=6.1e-12, max_dmdt=3339.75 ode_step=9.43137e-14
# step=62, time=6.2e-12, max_dmdt=3296.68 ode_step=9.43137e-14
# step=63, time=6.3e-12, max_dmdt=3254.45 ode_step=9.43137e-14
# step=64, time=6.4e-12, max_dmdt=3213.1 ode_step=9.43137e-14
# step=65, time=6.5e-12, max_dmdt=3172.62 ode_step=9.43137e-14
# step=66, time=6.6e-12, max_dmdt=3133.02 ode_step=9.43137e-14
# step=67, time=6.7e-12, max_dmdt=3094.31 ode_step=9.43137e-14
# step=68, time=6.8e-12, max_dmdt=3056.48 ode_step=9.43137e-14
# step=69, time=6.9e-12, max_dmdt=3019.53 ode_step=9.43137e-14
# step=70, time=7e-12, max_dmdt=2983.45 ode_step=9.43137e-14
# step=71, time=7.1e-12, max_dmdt=2948.23 ode_step=9.43137e-14
# step=72, time=7.2e-12, max_dmdt=2913.85 ode_step=9.43137e-14
# step=73, time=7.3e-12, max_dmdt=2880.31 ode_step=9.43137e-14
# step=74, time=7.4e-12, max_dmdt=2847.58 ode_step=9.43137e-14
# step=75, time=7.5e-12, max_dmdt=2815.66 ode_step=9.43137e-14
# step=76, time=7.6e-12, max_dmdt=2784.52 ode_step=9.43137e-14
# step=77, time=7.7e-12, max_dmdt=2754.14 ode_step=9.43137e-14
# step=78, time=7.8e-12, max_dmdt=2724.51 ode_step=9.43137e-14
# step=79, time=7.9e-12, max_dmdt=2695.61 ode_step=9.43137e-14
# step=80, time=8e-12, max_dmdt=2667.42 ode_step=9.43137e-14
# step=81, time=8.1e-12, max_dmdt=2639.92 ode_step=9.43137e-14
# step=82, time=8.2e-12, max_dmdt=2614.59 ode_step=9.43137e-14
# step=83, time=8.3e-12, max_dmdt=2598 ode_step=9.43137e-14
# step=84, time=8.4e-12, max_dmdt=2581.52 ode_step=9.43137e-14
# step=85, time=8.5e-12, max_dmdt=2565.15 ode_step=9.43137e-14
# step=86, time=8.6e-12, max_dmdt=2548.91 ode_step=9.43137e-14
# step=87, time=8.7e-12, max_dmdt=2532.82 ode_step=9.43137e-14
# step=88, time=8.8e-12, max_dmdt=2516.88 ode_step=9.43137e-14
# step=89, time=8.9e-12, max_dmdt=2501.11 ode_step=9.43137e-14
# step=90, time=9e-12, max_dmdt=2485.52 ode_step=9.43137e-14
# step=91, time=9.1e-12, max_dmdt=2470.11 ode_step=9.43137e-14
# step=92, time=9.2e-12, max_dmdt=2454.89 ode_step=9.43137e-14
# step=93, time=9.3e-12, max_dmdt=2439.87 ode_step=9.43137e-14
# step=94, time=9.4e-12, max_dmdt=2425.04 ode_step=9.43137e-14
# step=95, time=9.5e-12, max_dmdt=2410.41 ode_step=9.43137e-14
# step=96, time=9.6e-12, max_dmdt=2395.98 ode_step=9.43137e-14
# step=97, time=9.7e-12, max_dmdt=2381.76 ode_step=9.43137e-14
# step=98, time=9.8e-12, max_dmdt=2367.75 ode_step=9.43137e-14
# step=99, time=9.9e-12, max_dmdt=2353.94 ode_step=9.43137e-14
# step=100, time=1e-11, max_dmdt=2340.34 ode_step=9.43137e-14
# step=101, time=1.01e-11, max_dmdt=2326.94 ode_step=9.43137e-14
# step=102, time=1.02e-11, max_dmdt=2313.75 ode_step=9.43137e-14
# step=103, time=1.03e-11, max_dmdt=2300.77 ode_step=9.43137e-14
# step=104, time=1.04e-11, max_dmdt=2287.99 ode_step=9.43137e-14
# step=105, time=1.05e-11, max_dmdt=2275.41 ode_step=9.43137e-14
# step=106, time=1.06e-11, max_dmdt=2263.03 ode_step=9.43137e-14
# step=107, time=1.07e-11, max_dmdt=2250.85 ode_step=9.43137e-14
# step=108, time=1.08e-11, max_dmdt=2238.86 ode_step=9.43137e-14
# step=109, time=1.09475e-11, max_dmdt=2224.3 ode_step=1.47495e-13
# step=110, time=1.1095e-11, max_dmdt=2207.32 ode_step=1.47495e-13
# step=111, time=1.12425e-11, max_dmdt=2190.75 ode_step=1.47495e-13
# step=112, time=1.139e-11, max_dmdt=2174.57 ode_step=1.47495e-13
# step=113, time=1.15375e-11, max_dmdt=2158.78 ode_step=1.47495e-13
# step=114, time=1.1685e-11, max_dmdt=2143.36 ode_step=1.47495e-13
# step=115, time=1.18325e-11, max_dmdt=2128.31 ode_step=1.47495e-13
# step=116, time=1.198e-11, max_dmdt=2113.61 ode_step=1.47495e-13
# step=117, time=1.21275e-11, max_dmdt=2099.26 ode_step=1.47495e-13
# step=118, time=1.2275e-11, max_dmdt=2085.24 ode_step=1.47495e-13
# step=119, time=1.24224e-11, max_dmdt=2071.56 ode_step=1.47495e-13
# step=120, time=1.26482e-11, max_dmdt=2054.71 ode_step=2.25728e-13
# step=121, time=1.28739e-11, max_dmdt=2035.62 ode_step=2.25728e-13
# step=122, time=1.30996e-11, max_dmdt=2024.77 ode_step=2.25728e-13
# step=123, time=1.33254e-11, max_dmdt=2014.12 ode_step=2.25728e-13
# step=124, time=1.35511e-11, max_dmdt=2003.68 ode_step=2.25728e-13
# step=125, time=1.37768e-11, max_dmdt=1993.44 ode_step=2.25728e-13
# step=126, time=1.40025e-11, max_dmdt=1983.42 ode_step=2.25728e-13
# step=127, time=1.42283e-11, max_dmdt=1973.61 ode_step=2.25728e-13
# step=128, time=1.4454e-11, max_dmdt=1964.01 ode_step=2.25728e-13
# step=129, time=1.46797e-11, max_dmdt=1954.61 ode_step=2.25728e-13
# step=130, time=1.49055e-11, max_dmdt=1945.4 ode_step=2.25728e-13
# step=131, time=1.51312e-11, max_dmdt=1936.38 ode_step=2.25728e-13
# step=132, time=1.53569e-11, max_dmdt=1927.54 ode_step=2.25728e-13
# step=133, time=1.55826e-11, max_dmdt=1918.88 ode_step=2.25728e-13
# step=134, time=1.58084e-11, max_dmdt=1910.37 ode_step=2.25728e-13
# step=135, time=1.60341e-11, max_dmdt=1902.02 ode_step=2.25728e-13
# step=136, time=1.62598e-11, max_dmdt=1893.8 ode_step=2.25728e-13
# step=137, time=1.64856e-11, max_dmdt=1885.71 ode_step=2.25728e-13
# step=138, time=1.67113e-11, max_dmdt=1877.74 ode_step=2.25728e-13
# step=139, time=1.6937e-11, max_dmdt=1869.88 ode_step=2.25728e-13
# step=140, time=1.71627e-11, max_dmdt=1862.11 ode_step=2.25728e-13
# step=141, time=1.73885e-11, max_dmdt=1854.43 ode_step=2.25728e-13
# step=142, time=1.76142e-11, max_dmdt=1846.81 ode_step=2.25728e-13
# step=143, time=1.78399e-11, max_dmdt=1839.26 ode_step=2.25728e-13
# step=144, time=1.80656e-11, max_dmdt=1831.75 ode_step=2.25728e-13
# step=145, time=1.82914e-11, max_dmdt=1829.73 ode_step=2.25728e-13
# step=146, time=1.85171e-11, max_dmdt=1828.34 ode_step=2.25728e-13
# step=147, time=1.87428e-11, max_dmdt=1826.88 ode_step=2.25728e-13
# step=148, time=1.89686e-11, max_dmdt=1825.35 ode_step=2.25728e-13
# step=149, time=1.91943e-11, max_dmdt=1823.75 ode_step=2.25728e-13
# step=150, time=1.942e-11, max_dmdt=1822.06 ode_step=2.25728e-13
# step=151, time=1.96457e-11, max_dmdt=1820.29 ode_step=2.25728e-13
# step=152, time=1.99848e-11, max_dmdt=1817.96 ode_step=3.39029e-13
# step=153, time=2.03238e-11, max_dmdt=1814.97 ode_step=3.39029e-13
# step=154, time=2.06628e-11, max_dmdt=1811.75 ode_step=3.39029e-13
# step=155, time=2.10019e-11, max_dmdt=1808.28 ode_step=3.39029e-13
# step=156, time=2.13409e-11, max_dmdt=1804.51 ode_step=3.39029e-13
# step=157, time=2.16799e-11, max_dmdt=1800.43 ode_step=3.39029e-13
# step=158, time=2.20189e-11, max_dmdt=1796 ode_step=3.39029e-13
# step=159, time=2.2358e-11, max_dmdt=1791.18 ode_step=3.39029e-13
# step=160, time=2.2697e-11, max_dmdt=1785.92 ode_step=3.39029e-13
# step=161, time=2.3036e-11, max_dmdt=1780.78 ode_step=3.39029e-13
# step=162, time=2.33751e-11, max_dmdt=1783.58 ode_step=3.39029e-13
# step=163, time=2.37141e-11, max_dmdt=1785.79 ode_step=3.39029e-13
# step=164, time=2.40531e-11, max_dmdt=1787.4 ode_step=3.39029e-13
# step=165, time=2.43922e-11, max_dmdt=1788.39 ode_step=3.39029e-13
# step=166, time=2.47312e-11, max_dmdt=1788.8 ode_step=3.39029e-13
# step=167, time=2.50702e-11, max_dmdt=1788.61 ode_step=3.39029e-13
# step=168, time=2.54092e-11, max_dmdt=1787.84 ode_step=3.39029e-13
# step=169, time=2.57483e-11, max_dmdt=1786.51 ode_step=3.39029e-13
# step=170, time=2.60873e-11, max_dmdt=1784.62 ode_step=3.39029e-13
# step=171, time=2.64263e-11, max_dmdt=1782.2 ode_step=3.39029e-13
# step=172, time=2.67654e-11, max_dmdt=1779.25 ode_step=3.39029e-13
# step=173, time=2.71044e-11, max_dmdt=1775.78 ode_step=3.39029e-13
# step=174, time=2.74434e-11, max_dmdt=1773.57 ode_step=3.39029e-13
# step=175, time=2.77824e-11, max_dmdt=1780.17 ode_step=3.39029e-13
# step=176, time=2.81215e-11, max_dmdt=1786.28 ode_step=3.39029e-13
# step=177, time=2.84605e-11, max_dmdt=1791.86 ode_step=3.39029e-13
# step=178, time=2.87995e-11, max_dmdt=1796.88 ode_step=3.39029e-13
# step=179, time=2.91386e-11, max_dmdt=1801.29 ode_step=3.39029e-13
# step=180, time=2.94776e-11, max_dmdt=1805.06 ode_step=3.39029e-13
# step=181, time=2.98166e-11, max_dmdt=1808.13 ode_step=3.39029e-13
# step=182, time=3.01556e-11, max_dmdt=1810.47 ode_step=3.39029e-13
# step=183, time=3.04947e-11, max_dmdt=1812.03 ode_step=3.39029e-13
# step=184, time=3.08337e-11, max_dmdt=1812.76 ode_step=3.39029e-13
# step=185, time=3.11727e-11, max_dmdt=1812.63 ode_step=3.39029e-13
# step=186, time=3.15118e-11, max_dmdt=1820.43 ode_step=3.39029e-13
# step=187, time=3.18508e-11, max_dmdt=1829.17 ode_step=3.39029e-13
# step=188, time=3.21898e-11, max_dmdt=1836.8 ode_step=3.39029e-13
# step=189, time=3.25289e-11, max_dmdt=1843.3 ode_step=3.39029e-13
# step=190, time=3.28679e-11, max_dmdt=1848.61 ode_step=3.39029e-13
# step=191, time=3.33968e-11, max_dmdt=1853.57 ode_step=5.28901e-13
# step=192, time=3.39257e-11, max_dmdt=1856.95 ode_step=5.28901e-13
# step=193, time=3.44546e-11, max_dmdt=1857.26 ode_step=5.28901e-13
# step=194, time=3.49835e-11, max_dmdt=1854.45 ode_step=5.28901e-13
# step=195, time=3.55124e-11, max_dmdt=1848.53 ode_step=5.28901e-13
# step=196, time=3.60413e-11, max_dmdt=1839.51 ode_step=5.28901e-13
# step=197, time=3.65702e-11, max_dmdt=1840.86 ode_step=5.28901e-13
# step=198, time=3.70991e-11, max_dmdt=1842.04 ode_step=5.28901e-13
# step=199, time=3.7628e-11, max_dmdt=1840.3 ode_step=5.28901e-13
# step=200, time=3.81569e-11, max_dmdt=1835.68 ode_step=5.28901e-13
# step=201, time=3.86858e-11, max_dmdt=1828.22 ode_step=5.28901e-13
# step=202, time=3.92147e-11, max_dmdt=1818 ode_step=5.28901e-13
# step=203, time=3.97436e-11, max_dmdt=1805.1 ode_step=5.28901e-13
# step=204, time=4.02725e-11, max_dmdt=1789.6 ode_step=5.28901e-13
# step=205, time=4.08014e-11, max_dmdt=1771.99 ode_step=5.28901e-13
# step=206, time=4.13303e-11, max_dmdt=1771.47 ode_step=5.28901e-13
# step=207, time=4.18592e-11, max_dmdt=1768.65 ode_step=5.28901e-13
# step=208, time=4.23881e-11, max_dmdt=1763.53 ode_step=5.28901e-13
# step=209, time=4.2917e-11, max_dmdt=1756.16 ode_step=5.28901e-13
# step=210, time=4.34459e-11, max_dmdt=1746.57 ode_step=5.28901e-13
# step=211, time=4.39748e-11, max_dmdt=1734.81 ode_step=5.28901e-13
# step=212, time=4.45037e-11, max_dmdt=1720.95 ode_step=5.28901e-13
# step=213, time=4.50326e-11, max_dmdt=1727.56 ode_step=5.28901e-13
# step=214, time=4.55615e-11, max_dmdt=1732.91 ode_step=5.28901e-13
# step=215, time=4.60904e-11, max_dmdt=1736.11 ode_step=5.28901e-13
# step=216, time=4.66193e-11, max_dmdt=1737.14 ode_step=5.28901e-13
# step=217, time=4.71482e-11, max_dmdt=1736 ode_step=5.28901e-13
# step=218, time=4.76771e-11, max_dmdt=1732.69 ode_step=5.28901e-13
# step=219, time=4.8206e-11, max_dmdt=1750.36 ode_step=5.28901e-13
# step=220, time=4.87349e-11, max_dmdt=1768.24 ode_step=5.28901e-13
# step=221, time=4.92638e-11, max_dmdt=1783.81 ode_step=5.28901e-13
# step=222, time=4.97927e-11, max_dmdt=1797 ode_step=5.28901e-13
# step=223, time=5.03216e-11, max_dmdt=1807.78 ode_step=5.28901e-13
# step=224, time=5.08505e-11, max_dmdt=1821.27 ode_step=5.28901e-13
# step=225, time=5.13794e-11, max_dmdt=1853.48 ode_step=5.28901e-13
# step=226, time=5.19083e-11, max_dmdt=1883.2 ode_step=5.28901e-13
# step=227, time=5.24372e-11, max_dmdt=1910.33 ode_step=5.28901e-13
# step=228, time=5.29661e-11, max_dmdt=1934.77 ode_step=5.28901e-13
# step=229, time=5.3495e-11, max_dmdt=1956.43 ode_step=5.28901e-13
# step=230, time=5.40239e-11, max_dmdt=1986.3 ode_step=5.28901e-13
# step=231, time=5.45528e-11, max_dmdt=2028.37 ode_step=5.28901e-13
# step=232, time=5.50817e-11, max_dmdt=2067.65 ode_step=5.28901e-13
# step=233, time=5.56106e-11, max_dmdt=2103.98 ode_step=5.28901e-13
# step=234, time=5.61395e-11, max_dmdt=2137.21 ode_step=5.28901e-13
# step=235, time=5.66684e-11, max_dmdt=2167.18 ode_step=5.28901e-13
# step=236, time=5.70589e-11, max_dmdt=2194.95 ode_step=3.9048e-13
# step=237, time=5.74494e-11, max_dmdt=2231.49 ode_step=3.9048e-13
# step=238, time=5.78399e-11, max_dmdt=2266.31 ode_step=3.9048e-13
# step=239, time=5.82303e-11, max_dmdt=2299.34 ode_step=3.9048e-13
# step=240, time=5.86208e-11, max_dmdt=2330.46 ode_step=3.9048e-13
# step=241, time=5.90113e-11, max_dmdt=2359.59 ode_step=3.9048e-13
# step=242, time=5.94018e-11, max_dmdt=2386.64 ode_step=3.9048e-13
# step=243, time=5.97923e-11, max_dmdt=2411.52 ode_step=3.9048e-13
# step=244, time=6.00798e-11, max_dmdt=2431.34 ode_step=2.87542e-13
# step=245, time=6.03673e-11, max_dmdt=2446.73 ode_step=2.87542e-13
# step=246, time=6.06549e-11, max_dmdt=2469.65 ode_step=2.87542e-13
# step=247, time=6.09424e-11, max_dmdt=2496.19 ode_step=2.87542e-13
# step=248, time=6.123e-11, max_dmdt=2521.54 ode_step=2.87542e-13
# step=249, time=6.15175e-11, max_dmdt=2545.65 ode_step=2.87542e-13
# step=250, time=6.1805e-11, max_dmdt=2568.47 ode_step=2.87542e-13
# step=251, time=6.20926e-11, max_dmdt=2589.95 ode_step=2.87542e-13
# step=252, time=6.23801e-11, max_dmdt=2610.05 ode_step=2.87542e-13
# step=253, time=6.26677e-11, max_dmdt=2628.7 ode_step=2.87542e-13
# step=254, time=6.29552e-11, max_dmdt=2645.88 ode_step=2.87542e-13
# step=255, time=6.32428e-11, max_dmdt=2661.52 ode_step=2.87542e-13
# step=256, time=6.35303e-11, max_dmdt=2675.59 ode_step=2.87542e-13
# step=257, time=6.38178e-11, max_dmdt=2688.04 ode_step=2.87542e-13
# step=258, time=6.41054e-11, max_dmdt=2698.82 ode_step=2.87542e-13
# step=259, time=6.43929e-11, max_dmdt=2707.92 ode_step=2.87542e-13
# step=260, time=6.46805e-11, max_dmdt=2725.98 ode_step=2.87542e-13
# step=261, time=6.4968e-11, max_dmdt=2745.75 ode_step=2.87542e-13
# step=262, time=6.52555e-11, max_dmdt=2763.87 ode_step=2.87542e-13
# step=263, time=6.55431e-11, max_dmdt=2780.26 ode_step=2.87542e-13
# step=264, time=6.58306e-11, max_dmdt=2794.88 ode_step=2.87542e-13
# step=265, time=6.61182e-11, max_dmdt=2807.67 ode_step=2.87542e-13
# step=266, time=6.64057e-11, max_dmdt=2818.56 ode_step=2.87542e-13
# step=267, time=6.66186e-11, max_dmdt=2826.51 ode_step=2.12855e-13
# step=268, time=6.68314e-11, max_dmdt=2832.06 ode_step=2.12855e-13
# step=269, time=6.70443e-11, max_dmdt=2836.51 ode_step=2.12855e-13
# step=270, time=6.72571e-11, max_dmdt=2839.83 ode_step=2.12855e-13
# step=271, time=6.747e-11, max_dmdt=2842.02 ode_step=2.12855e-13
# step=272, time=6.76828e-11, max_dmdt=2843.06 ode_step=2.12855e-13
# step=273, time=6.78957e-11, max_dmdt=2842.94 ode_step=2.12855e-13
# step=274, time=6.81086e-11, max_dmdt=2841.63 ode_step=2.12855e-13
# step=275, time=6.83214e-11, max_dmdt=2839.14 ode_step=2.12855e-13
# step=276, time=6.85343e-11, max_dmdt=2835.46 ode_step=2.12855e-13
# step=277, time=6.87471e-11, max_dmdt=2830.57 ode_step=2.12855e-13
# step=278, time=6.896e-11, max_dmdt=2826.9 ode_step=2.12855e-13
# step=279, time=6.91728e-11, max_dmdt=2830.58 ode_step=2.12855e-13
# step=280, time=6.93857e-11, max_dmdt=2833.04 ode_step=2.12855e-13
# step=281, time=6.95985e-11, max_dmdt=2834.27 ode_step=2.12855e-13
# step=282, time=6.98114e-11, max_dmdt=2834.24 ode_step=2.12855e-13
# step=283, time=7.00242e-11, max_dmdt=2832.93 ode_step=2.12855e-13
# step=284, time=7.02371e-11, max_dmdt=2830.34 ode_step=2.12855e-13
# step=285, time=7.045e-11, max_dmdt=2826.45 ode_step=2.12855e-13
# step=286, time=7.06628e-11, max_dmdt=2821.24 ode_step=2.12855e-13
# step=287, time=7.08757e-11, max_dmdt=2814.71 ode_step=2.12855e-13
# step=288, time=7.10885e-11, max_dmdt=2806.85 ode_step=2.12855e-13
# step=289, time=7.13014e-11, max_dmdt=2797.65 ode_step=2.12855e-13
# step=290, time=7.15142e-11, max_dmdt=2787.11 ode_step=2.12855e-13
# step=291, time=7.17271e-11, max_dmdt=2775.23 ode_step=2.12855e-13
# step=292, time=7.19399e-11, max_dmdt=2762 ode_step=2.12855e-13
# step=293, time=7.21528e-11, max_dmdt=2747.43 ode_step=2.12855e-13
# step=294, time=7.23656e-11, max_dmdt=2731.53 ode_step=2.12855e-13
# step=295, time=7.25785e-11, max_dmdt=2714.31 ode_step=2.12855e-13
# step=296, time=7.27914e-11, max_dmdt=2695.76 ode_step=2.12855e-13
# step=297, time=7.30042e-11, max_dmdt=2675.91 ode_step=2.12855e-13
# step=298, time=7.32171e-11, max_dmdt=2654.78 ode_step=2.12855e-13
# step=299, time=7.34299e-11, max_dmdt=2632.37 ode_step=2.12855e-13
# step=300, time=7.36428e-11, max_dmdt=2608.7 ode_step=2.12855e-13
# step=301, time=7.38556e-11, max_dmdt=2583.8 ode_step=2.12855e-13
# step=302, time=7.40685e-11, max_dmdt=2557.69 ode_step=2.12855e-13
# step=303, time=7.42813e-11, max_dmdt=2535.81 ode_step=2.12855e-13
# step=304, time=7.44942e-11, max_dmdt=2516.97 ode_step=2.12855e-13
# step=305, time=7.4707e-11, max_dmdt=2496.74 ode_step=2.12855e-13
# step=306, time=7.49199e-11, max_dmdt=2475.12 ode_step=2.12855e-13
# step=307, time=7.51328e-11, max_dmdt=2452.12 ode_step=2.12855e-13
# step=308, time=7.53456e-11, max_dmdt=2427.77 ode_step=2.12855e-13
# step=309, time=7.55585e-11, max_dmdt=2402.09 ode_step=2.12855e-13
# step=310, time=7.57713e-11, max_dmdt=2375.09 ode_step=2.12855e-13
# step=311, time=7.59842e-11, max_dmdt=2346.8 ode_step=2.12855e-13
# step=312, time=7.6197e-11, max_dmdt=2317.25 ode_step=2.12855e-13
# step=313, time=7.64099e-11, max_dmdt=2286.47 ode_step=2.12855e-13
# step=314, time=7.66227e-11, max_dmdt=2254.49 ode_step=2.12855e-13
# step=315, time=7.68356e-11, max_dmdt=2221.35 ode_step=2.12855e-13
# step=316, time=7.70484e-11, max_dmdt=2187.08 ode_step=2.12855e-13
# step=317, time=7.72613e-11, max_dmdt=2151.72 ode_step=2.12855e-13
# step=318, time=7.74742e-11, max_dmdt=2115.33 ode_step=2.12855e-13
# step=319, time=7.7687e-11, max_dmdt=2077.93 ode_step=2.12855e-13
# step=320, time=7.78999e-11, max_dmdt=2039.57 ode_step=2.12855e-13
# step=321, time=7.81127e-11, max_dmdt=2000.31 ode_step=2.12855e-13
# step=322, time=7.83256e-11, max_dmdt=1960.19 ode_step=2.12855e-13
# step=323, time=7.85384e-11, max_dmdt=1919.26 ode_step=2.12855e-13
# step=324, time=7.87513e-11, max_dmdt=1877.57 ode_step=2.12855e-13
# step=325, time=7.89641e-11, max_dmdt=1846.27 ode_step=2.12855e-13
# step=326, time=7.9177e-11, max_dmdt=1865.59 ode_step=2.12855e-13
# step=327, time=7.93898e-11, max_dmdt=1883.6 ode_step=2.12855e-13
# step=328, time=7.96027e-11, max_dmdt=1900.29 ode_step=2.12855e-13
# step=329, time=7.99241e-11, max_dmdt=1919.3 ode_step=3.21398e-13
# step=330, time=8.02455e-11, max_dmdt=1939.49 ode_step=3.21398e-13
# step=331, time=8.05669e-11, max_dmdt=1956.68 ode_step=3.21398e-13
# step=332, time=8.08883e-11, max_dmdt=1970.88 ode_step=3.21398e-13
# step=333, time=8.12097e-11, max_dmdt=1982.1 ode_step=3.21398e-13
# step=334, time=8.15311e-11, max_dmdt=1990.39 ode_step=3.21398e-13
# step=335, time=8.18525e-11, max_dmdt=1995.79 ode_step=3.21398e-13
# step=336, time=8.21739e-11, max_dmdt=1998.35 ode_step=3.21398e-13
# step=337, time=8.24953e-11, max_dmdt=1998.13 ode_step=3.21398e-13
# step=338, time=8.28167e-11, max_dmdt=1995.19 ode_step=3.21398e-13
# step=339, time=8.31381e-11, max_dmdt=1989.59 ode_step=3.21398e-13
# step=340, time=8.34595e-11, max_dmdt=1981.43 ode_step=3.21398e-13
# step=341, time=8.37809e-11, max_dmdt=1970.78 ode_step=3.21398e-13
# step=342, time=8.41023e-11, max_dmdt=1957.73 ode_step=3.21398e-13
# step=343, time=8.44237e-11, max_dmdt=1942.36 ode_step=3.21398e-13
# step=344, time=8.47451e-11, max_dmdt=1924.78 ode_step=3.21398e-13
# step=345, time=8.50665e-11, max_dmdt=1905.08 ode_step=3.21398e-13
# step=346, time=8.53879e-11, max_dmdt=1883.35 ode_step=3.21398e-13
# step=347, time=8.57093e-11, max_dmdt=1859.72 ode_step=3.21398e-13
# step=348, time=8.60307e-11, max_dmdt=1834.81 ode_step=3.21398e-13
# step=349, time=8.63521e-11, max_dmdt=1807.84 ode_step=3.21398e-13
# step=350, time=8.66735e-11, max_dmdt=1778.94 ode_step=3.21398e-13
# step=351, time=8.69949e-11, max_dmdt=1748.24 ode_step=3.21398e-13
# step=352, time=8.73163e-11, max_dmdt=1716.36 ode_step=3.21398e-13
# step=353, time=8.76377e-11, max_dmdt=1683.4 ode_step=3.21398e-13
# step=354, time=8.79591e-11, max_dmdt=1649.25 ode_step=3.21398e-13
# step=355, time=8.82804e-11, max_dmdt=1614.01 ode_step=3.21398e-13
# step=356, time=8.86018e-11, max_dmdt=1577.79 ode_step=3.21398e-13
# step=357, time=8.89232e-11, max_dmdt=1540.68 ode_step=3.21398e-13
# step=358, time=8.92446e-11, max_dmdt=1502.78 ode_step=3.21398e-13
# step=359, time=8.9566e-11, max_dmdt=1464.18 ode_step=3.21398e-13
# step=360, time=8.98874e-11, max_dmdt=1424.99 ode_step=3.21398e-13
# step=361, time=9.02088e-11, max_dmdt=1385.28 ode_step=3.21398e-13
# step=362, time=9.05302e-11, max_dmdt=1345.15 ode_step=3.21398e-13
# step=363, time=9.08516e-11, max_dmdt=1304.68 ode_step=3.21398e-13
# step=364, time=9.1173e-11, max_dmdt=1263.94 ode_step=3.21398e-13
# step=365, time=9.14944e-11, max_dmdt=1223.03 ode_step=3.21398e-13
# step=366, time=9.18158e-11, max_dmdt=1182.02 ode_step=3.21398e-13
# step=367, time=9.21372e-11, max_dmdt=1140.97 ode_step=3.21398e-13
# step=368, time=9.24586e-11, max_dmdt=1099.96 ode_step=3.21398e-13
# step=369, time=9.278e-11, max_dmdt=1059.05 ode_step=3.21398e-13
# step=370, time=9.31014e-11, max_dmdt=1018.3 ode_step=3.21398e-13
# step=371, time=9.34228e-11, max_dmdt=977.782 ode_step=3.21398e-13
# step=372, time=9.37442e-11, max_dmdt=937.887 ode_step=3.21398e-13
# step=373, time=9.40656e-11, max_dmdt=900.627 ode_step=3.21398e-13
# step=374, time=9.4387e-11, max_dmdt=863.619 ode_step=3.21398e-13
# step=375, time=9.47084e-11, max_dmdt=826.906 ode_step=3.21398e-13
# step=376, time=9.50298e-11, max_dmdt=790.528 ode_step=3.21398e-13
# step=377, time=9.53512e-11, max_dmdt=800.18 ode_step=3.21398e-13
# step=378, time=9.56726e-11, max_dmdt=810.791 ode_step=3.21398e-13
# step=379, time=9.5994e-11, max_dmdt=820.107 ode_step=3.21398e-13
# step=380, time=9.63154e-11, max_dmdt=828.165 ode_step=3.21398e-13
# step=381, time=9.66368e-11, max_dmdt=835.001 ode_step=3.21398e-13
# step=382, time=9.69582e-11, max_dmdt=840.654 ode_step=3.21398e-13
# step=383, time=9.74442e-11, max_dmdt=846.077 ode_step=4.85997e-13
# step=384, time=9.79302e-11, max_dmdt=850.391 ode_step=4.85997e-13
# step=385, time=9.84162e-11, max_dmdt=852.333 ode_step=4.85997e-13
# step=386, time=9.89022e-11, max_dmdt=852.037 ode_step=4.85997e-13
# step=387, time=9.93882e-11, max_dmdt=849.637 ode_step=4.85997e-13
# step=388, time=9.98742e-11, max_dmdt=845.269 ode_step=4.85997e-13
# step=389, time=1.0036e-10, max_dmdt=839.063 ode_step=4.85997e-13
# step=390, time=1.00846e-10, max_dmdt=831.149 ode_step=4.85997e-13
# step=391, time=1.01332e-10, max_dmdt=821.798 ode_step=4.85997e-13
# step=392, time=1.01818e-10, max_dmdt=813.416 ode_step=4.85997e-13
# step=393, time=1.02304e-10, max_dmdt=803.581 ode_step=4.85997e-13
# step=394, time=1.0279e-10, max_dmdt=792.402 ode_step=4.85997e-13
# step=395, time=1.03276e-10, max_dmdt=779.983 ode_step=4.85997e-13
# step=396, time=1.03762e-10, max_dmdt=766.425 ode_step=4.85997e-13
# step=397, time=1.04248e-10, max_dmdt=751.829 ode_step=4.85997e-13
# step=398, time=1.04978e-10, max_dmdt=732.219 ode_step=7.2937e-13
# step=399, time=1.05707e-10, max_dmdt=707.048 ode_step=7.2937e-13
# step=400, time=1.06436e-10, max_dmdt=680.309 ode_step=7.2937e-13
# step=401, time=1.07166e-10, max_dmdt=653.848 ode_step=7.2937e-13
# step=402, time=1.07895e-10, max_dmdt=627.244 ode_step=7.2937e-13
# step=403, time=1.08624e-10, max_dmdt=599.57 ode_step=7.2937e-13
# step=404, time=1.09354e-10, max_dmdt=571.054 ode_step=7.2937e-13
# step=405, time=1.10083e-10, max_dmdt=541.908 ode_step=7.2937e-13
# step=406, time=1.10812e-10, max_dmdt=512.329 ode_step=7.2937e-13
# step=407, time=1.11542e-10, max_dmdt=484.438 ode_step=7.2937e-13
# step=408, time=1.12271e-10, max_dmdt=456.26 ode_step=7.2937e-13
# step=409, time=1.13001e-10, max_dmdt=427.928 ode_step=7.2937e-13
# step=410, time=1.1373e-10, max_dmdt=399.827 ode_step=7.2937e-13
# step=411, time=1.14459e-10, max_dmdt=373.329 ode_step=7.2937e-13
# step=412, time=1.15189e-10, max_dmdt=346.891 ode_step=7.2937e-13
# step=413, time=1.15918e-10, max_dmdt=321.551 ode_step=7.2937e-13
# step=414, time=1.16647e-10, max_dmdt=299.774 ode_step=7.2937e-13
# step=415, time=1.17377e-10, max_dmdt=299.254 ode_step=7.2937e-13
# step=416, time=1.18106e-10, max_dmdt=297.496 ode_step=7.2937e-13
# step=417, time=1.18836e-10, max_dmdt=295.015 ode_step=7.2937e-13
# step=418, time=1.19565e-10, max_dmdt=291.92 ode_step=7.2937e-13
# step=419, time=1.20294e-10, max_dmdt=287.807 ode_step=7.2937e-13
# step=420, time=1.21024e-10, max_dmdt=282.77 ode_step=7.2937e-13
# step=421, time=1.21753e-10, max_dmdt=276.9 ode_step=7.2937e-13
# step=422, time=1.22482e-10, max_dmdt=270.284 ode_step=7.2937e-13
# step=423, time=1.23212e-10, max_dmdt=263.003 ode_step=7.2937e-13
# step=424, time=1.23941e-10, max_dmdt=255.136 ode_step=7.2937e-13
# step=425, time=1.24671e-10, max_dmdt=246.973 ode_step=7.2937e-13
# step=426, time=1.254e-10, max_dmdt=238.631 ode_step=7.2937e-13
# step=427, time=1.26129e-10, max_dmdt=229.86 ode_step=7.2937e-13
# step=428, time=1.26859e-10, max_dmdt=220.724 ode_step=7.2937e-13
# step=429, time=1.27588e-10, max_dmdt=211.284 ode_step=7.2937e-13
# step=430, time=1.28317e-10, max_dmdt=201.6 ode_step=7.2937e-13
# step=431, time=1.29047e-10, max_dmdt=191.759 ode_step=7.2937e-13
# step=432, time=1.29776e-10, max_dmdt=182.141 ode_step=7.2937e-13
# step=433, time=1.30505e-10, max_dmdt=172.396 ode_step=7.2937e-13
# step=434, time=1.31235e-10, max_dmdt=162.568 ode_step=7.2937e-13
# step=435, time=1.31964e-10, max_dmdt=152.82 ode_step=7.2937e-13
# step=436, time=1.32694e-10, max_dmdt=143.344 ode_step=7.2937e-13
# step=437, time=1.33423e-10, max_dmdt=133.883 ode_step=7.2937e-13
# step=438, time=1.34152e-10, max_dmdt=124.879 ode_step=7.2937e-13
# step=439, time=1.34882e-10, max_dmdt=116.125 ode_step=7.2937e-13
# step=440, time=1.35611e-10, max_dmdt=117.674 ode_step=7.2937e-13
# step=441, time=1.3634e-10, max_dmdt=120.898 ode_step=7.2937e-13
# step=442, time=1.3707e-10, max_dmdt=123.448 ode_step=7.2937e-13
# step=443, time=1.37799e-10, max_dmdt=125.358 ode_step=7.2937e-13
# step=444, time=1.38529e-10, max_dmdt=126.658 ode_step=7.2937e-13
# step=445, time=1.39258e-10, max_dmdt=127.381 ode_step=7.2937e-13
# step=446, time=1.39987e-10, max_dmdt=127.563 ode_step=7.2937e-13
# step=447, time=1.40717e-10, max_dmdt=127.236 ode_step=7.2937e-13
# step=448, time=1.41446e-10, max_dmdt=126.43 ode_step=7.2937e-13
# step=449, time=1.42175e-10, max_dmdt=125.179 ode_step=7.2937e-13
# step=450, time=1.42905e-10, max_dmdt=123.519 ode_step=7.2937e-13
# step=451, time=1.43634e-10, max_dmdt=121.52 ode_step=7.2937e-13
# step=452, time=1.44363e-10, max_dmdt=119.309 ode_step=7.2937e-13
# step=453, time=1.45093e-10, max_dmdt=116.763 ode_step=7.2937e-13
# step=454, time=1.45822e-10, max_dmdt=113.912 ode_step=7.2937e-13
# step=455, time=1.46552e-10, max_dmdt=110.791 ode_step=7.2937e-13
# step=456, time=1.47281e-10, max_dmdt=107.427 ode_step=7.2937e-13
# step=457, time=1.4801e-10, max_dmdt=103.843 ode_step=7.2937e-13
# step=458, time=1.4874e-10, max_dmdt=100.07 ode_step=7.2937e-13
# step=459, time=1.49469e-10, max_dmdt=96.1393 ode_step=7.2937e-13
# step=460, time=1.50198e-10, max_dmdt=92.1118 ode_step=7.2937e-13
# step=461, time=1.50928e-10, max_dmdt=88.0721 ode_step=7.2937e-13
# step=462, time=1.51466e-10, max_dmdt=84.4749 ode_step=5.38053e-13
# step=463, time=1.52004e-10, max_dmdt=81.369 ode_step=5.38053e-13
# step=464, time=1.52542e-10, max_dmdt=78.2338 ode_step=5.38053e-13
# step=465, time=1.5308e-10, max_dmdt=75.0719 ode_step=5.38053e-13
# step=466, time=1.53618e-10, max_dmdt=71.95 ode_step=5.38053e-13
# step=467, time=1.54156e-10, max_dmdt=68.8619 ode_step=5.38053e-13
# step=468, time=1.54552e-10, max_dmdt=66.1655 ode_step=3.95616e-13
# step=469, time=1.54947e-10, max_dmdt=63.8789 ode_step=3.95616e-13
# step=470, time=1.55343e-10, max_dmdt=61.669 ode_step=3.95616e-13
# step=471, time=1.55739e-10, max_dmdt=59.4658 ode_step=3.95616e-13
# step=472, time=1.56134e-10, max_dmdt=57.2768 ode_step=3.95616e-13
# step=473, time=1.5653e-10, max_dmdt=55.1681 ode_step=3.95616e-13
# step=474, time=1.56925e-10, max_dmdt=53.079 ode_step=3.95616e-13
# step=475, time=1.57321e-10, max_dmdt=51.0699 ode_step=3.95616e-13
# step=476, time=1.57614e-10, max_dmdt=49.3572 ode_step=2.92768e-13
# step=477, time=1.57907e-10, max_dmdt=47.9496 ode_step=2.92768e-13
# step=478, time=1.58199e-10, max_dmdt=47.5487 ode_step=2.92768e-13
# step=479, time=1.58492e-10, max_dmdt=47.5936 ode_step=2.92768e-13
# step=480, time=1.58785e-10, max_dmdt=47.614 ode_step=2.92768e-13
# step=481, time=1.59078e-10, max_dmdt=47.6023 ode_step=2.92768e-13
# step=482, time=1.5937e-10, max_dmdt=47.5527 ode_step=2.92768e-13
# step=483, time=1.59663e-10, max_dmdt=47.4719 ode_step=2.92768e-13
# step=484, time=1.59956e-10, max_dmdt=47.3703 ode_step=2.92768e-13
# step=485, time=1.60249e-10, max_dmdt=47.2463 ode_step=2.92768e-13
# step=486, time=1.60542e-10, max_dmdt=47.0898 ode_step=2.92768e-13
# step=487, time=1.60834e-10, max_dmdt=46.8992 ode_step=2.92768e-13
# step=488, time=1.61127e-10, max_dmdt=46.705 ode_step=2.92768e-13
# step=489, time=1.6142e-10, max_dmdt=46.4864 ode_step=2.92768e-13
# step=490, time=1.61713e-10, max_dmdt=46.2426 ode_step=2.92768e-13
# step=491, time=1.62005e-10, max_dmdt=45.9862 ode_step=2.92768e-13
# step=492, time=1.62298e-10, max_dmdt=45.7131 ode_step=2.92768e-13
# step=493, time=1.62591e-10, max_dmdt=45.4087 ode_step=2.92768e-13
# step=494, time=1.62884e-10, max_dmdt=45.0728 ode_step=2.92768e-13
# step=495, time=1.63176e-10, max_dmdt=44.7214 ode_step=2.92768e-13
# step=496, time=1.63469e-10, max_dmdt=44.3628 ode_step=2.92768e-13
# step=497, time=1.63686e-10, max_dmdt=44.0364 ode_step=2.17153e-13
# step=498, time=1.63904e-10, max_dmdt=43.7364 ode_step=2.17153e-13
# step=499, time=1.64121e-10, max_dmdt=43.4218 ode_step=2.17153e-13
# step=500, time=1.64338e-10, max_dmdt=43.1038 ode_step=2.17153e-13
# step=501, time=1.64555e-10, max_dmdt=42.7845 ode_step=2.17153e-13
# step=502, time=1.64772e-10, max_dmdt=42.4556 ode_step=2.17153e-13
# step=503, time=1.64989e-10, max_dmdt=42.1108 ode_step=2.17153e-13
# step=504, time=1.65206e-10, max_dmdt=41.7536 ode_step=2.17153e-13
# step=505, time=1.65424e-10, max_dmdt=41.3924 ode_step=2.17153e-13
# step=506, time=1.65641e-10, max_dmdt=41.0294 ode_step=2.17153e-13
# step=507, time=1.65858e-10, max_dmdt=40.6587 ode_step=2.17153e-13
# step=508, time=1.66075e-10, max_dmdt=40.275 ode_step=2.17153e-13
# step=509, time=1.66292e-10, max_dmdt=39.8808 ode_step=2.17153e-13
# step=510, time=1.66509e-10, max_dmdt=39.483 ode_step=2.17153e-13
# step=511, time=1.66726e-10, max_dmdt=39.0838 ode_step=2.17153e-13
# step=512, time=1.66944e-10, max_dmdt=38.6786 ode_step=2.17153e-13
# step=513, time=1.67161e-10, max_dmdt=38.2627 ode_step=2.17153e-13
# step=514, time=1.67378e-10, max_dmdt=37.8378 ode_step=2.17153e-13
# step=515, time=1.67595e-10, max_dmdt=37.41 ode_step=2.17153e-13
# step=516, time=1.67812e-10, max_dmdt=36.9816 ode_step=2.17153e-13
# step=517, time=1.68029e-10, max_dmdt=36.5544 ode_step=2.17153e-13
# step=518, time=1.68247e-10, max_dmdt=36.1277 ode_step=2.17153e-13
# step=519, time=1.68464e-10, max_dmdt=35.6988 ode_step=2.17153e-13
# step=520, time=1.68681e-10, max_dmdt=35.2619 ode_step=2.17153e-13
# step=521, time=1.68898e-10, max_dmdt=34.8163 ode_step=2.17153e-13
# step=522, time=1.69115e-10, max_dmdt=34.3673 ode_step=2.17153e-13
# step=523, time=1.69332e-10, max_dmdt=33.9189 ode_step=2.17153e-13
# step=524, time=1.69549e-10, max_dmdt=33.4687 ode_step=2.17153e-13
# step=525, time=1.69767e-10, max_dmdt=33.0121 ode_step=2.17153e-13
# step=526, time=1.69984e-10, max_dmdt=32.5492 ode_step=2.17153e-13
# step=527, time=1.70201e-10, max_dmdt=32.0841 ode_step=2.17153e-13
# step=528, time=1.70418e-10, max_dmdt=31.6197 ode_step=2.17153e-13
# step=529, time=1.70635e-10, max_dmdt=31.1538 ode_step=2.17153e-13
# step=530, time=1.70852e-10, max_dmdt=30.6834 ode_step=2.17153e-13
# step=531, time=1.7107e-10, max_dmdt=30.2087 ode_step=2.17153e-13
# step=532, time=1.71287e-10, max_dmdt=29.7328 ode_step=2.17153e-13
# step=533, time=1.71504e-10, max_dmdt=29.2628 ode_step=2.17153e-13
# step=534, time=1.71721e-10, max_dmdt=28.7961 ode_step=2.17153e-13
# step=535, time=1.71938e-10, max_dmdt=28.3287 ode_step=2.17153e-13
# step=536, time=1.72155e-10, max_dmdt=27.8619 ode_step=2.17153e-13
# step=537, time=1.72372e-10, max_dmdt=27.3945 ode_step=2.17153e-13
# step=538, time=1.7259e-10, max_dmdt=26.9246 ode_step=2.17153e-13
# step=539, time=1.72807e-10, max_dmdt=26.4523 ode_step=2.17153e-13
# step=540, time=1.73024e-10, max_dmdt=25.9795 ode_step=2.17153e-13
# step=541, time=1.73241e-10, max_dmdt=25.5081 ode_step=2.17153e-13
# step=542, time=1.73458e-10, max_dmdt=25.0439 ode_step=2.17153e-13
# step=543, time=1.73675e-10, max_dmdt=24.5849 ode_step=2.17153e-13
# step=544, time=1.73893e-10, max_dmdt=24.1273 ode_step=2.17153e-13
# step=545, time=1.7411e-10, max_dmdt=23.6696 ode_step=2.17153e-13
# step=546, time=1.74327e-10, max_dmdt=23.2102 ode_step=2.17153e-13
# step=547, time=1.74544e-10, max_dmdt=22.7592 ode_step=2.17153e-13
# step=548, time=1.74761e-10, max_dmdt=22.3162 ode_step=2.17153e-13
# step=549, time=1.74978e-10, max_dmdt=21.8722 ode_step=2.17153e-13
# step=550, time=1.75195e-10, max_dmdt=21.4309 ode_step=2.17153e-13
# step=551, time=1.75413e-10, max_dmdt=21.005 ode_step=2.17153e-13
# step=552, time=1.7563e-10, max_dmdt=20.5782 ode_step=2.17153e-13
# step=553, time=1.75847e-10, max_dmdt=20.1593 ode_step=2.17153e-13
# step=554, time=1.76064e-10, max_dmdt=19.7513 ode_step=2.17153e-13
# step=555, time=1.76281e-10, max_dmdt=19.3427 ode_step=2.17153e-13
# step=556, time=1.76498e-10, max_dmdt=19.3351 ode_step=2.17153e-13
# step=557, time=1.76716e-10, max_dmdt=19.5291 ode_step=2.17153e-13
# step=558, time=1.76933e-10, max_dmdt=19.7131 ode_step=2.17153e-13
# step=559, time=1.7715e-10, max_dmdt=19.8872 ode_step=2.17153e-13
# step=560, time=1.77367e-10, max_dmdt=20.0512 ode_step=2.17153e-13
# step=561, time=1.77693e-10, max_dmdt=20.2413 ode_step=3.26111e-13
# step=562, time=1.78019e-10, max_dmdt=20.4496 ode_step=3.26111e-13
# step=563, time=1.78345e-10, max_dmdt=20.6366 ode_step=3.26111e-13
# step=564, time=1.78671e-10, max_dmdt=20.8027 ode_step=3.26111e-13
# step=565, time=1.78998e-10, max_dmdt=20.9479 ode_step=3.26111e-13
# step=566, time=1.79324e-10, max_dmdt=21.0725 ode_step=3.26111e-13
# step=567, time=1.7965e-10, max_dmdt=21.1771 ode_step=3.26111e-13
# step=568, time=1.79976e-10, max_dmdt=21.2625 ode_step=3.26111e-13
# step=569, time=1.80302e-10, max_dmdt=21.3402 ode_step=3.26111e-13
# step=570, time=1.80808e-10, max_dmdt=21.4158 ode_step=5.05703e-13
# step=571, time=1.81313e-10, max_dmdt=21.4695 ode_step=5.05703e-13
# step=572, time=1.81819e-10, max_dmdt=21.481 ode_step=5.05703e-13
# step=573, time=1.82325e-10, max_dmdt=21.4518 ode_step=5.05703e-13
# step=574, time=1.8283e-10, max_dmdt=21.3838 ode_step=5.05703e-13
# step=575, time=1.83336e-10, max_dmdt=21.2791 ode_step=5.05703e-13
# step=576, time=1.83842e-10, max_dmdt=21.1394 ode_step=5.05703e-13
# step=577, time=1.84348e-10, max_dmdt=20.9662 ode_step=5.05703e-13
# step=578, time=1.85173e-10, max_dmdt=20.6885 ode_step=8.25637e-13
# step=579, time=1.85999e-10, max_dmdt=20.2763 ode_step=8.25637e-13
# step=580, time=1.86825e-10, max_dmdt=19.7927 ode_step=8.25637e-13
# step=581, time=1.8765e-10, max_dmdt=19.2491 ode_step=8.25637e-13
# step=582, time=1.88476e-10, max_dmdt=18.6692 ode_step=8.25637e-13
# step=583, time=1.89301e-10, max_dmdt=18.0375 ode_step=8.25637e-13
# step=584, time=1.90127e-10, max_dmdt=17.3604 ode_step=8.25637e-13
# step=585, time=1.90953e-10, max_dmdt=16.6442 ode_step=8.25637e-13
# step=586, time=1.91778e-10, max_dmdt=15.895 ode_step=8.25637e-13
# step=587, time=1.93054e-10, max_dmdt=14.9152 ode_step=1.27518e-12
# step=588, time=1.94329e-10, max_dmdt=13.7004 ode_step=1.27518e-12
# step=589, time=1.95604e-10, max_dmdt=12.4649 ode_step=1.27518e-12
# step=590, time=1.96879e-10, max_dmdt=11.2417 ode_step=1.27518e-12
# step=591, time=1.98154e-10, max_dmdt=10.0601 ode_step=1.27518e-12
# step=592, time=1.99429e-10, max_dmdt=8.96017 ode_step=1.27518e-12
# step=593, time=2.00705e-10, max_dmdt=8.01072 ode_step=1.27518e-12
# step=594, time=2.0198e-10, max_dmdt=8.01868 ode_step=1.27518e-12
# step=595, time=2.03255e-10, max_dmdt=7.93562 ode_step=1.27518e-12
# step=596, time=2.0453e-10, max_dmdt=7.77174 ode_step=1.27518e-12
# step=597, time=2.05805e-10, max_dmdt=7.53706 ode_step=1.27518e-12
# step=598, time=2.0708e-10, max_dmdt=7.25076 ode_step=1.27518e-12
# step=599, time=2.08356e-10, max_dmdt=6.91373 ode_step=1.27518e-12
# step=600, time=2.09631e-10, max_dmdt=6.53306 ode_step=1.27518e-12
# step=601, time=2.10906e-10, max_dmdt=6.11744 ode_step=1.27518e-12
# step=602, time=2.12181e-10, max_dmdt=5.68298 ode_step=1.27518e-12
# step=603, time=2.13456e-10, max_dmdt=5.23044 ode_step=1.27518e-12
# step=604, time=2.14732e-10, max_dmdt=4.77179 ode_step=1.27518e-12
# step=605, time=2.16007e-10, max_dmdt=4.31467 ode_step=1.27518e-12
# step=606, time=2.17282e-10, max_dmdt=3.87271 ode_step=1.27518e-12
# step=607, time=2.18557e-10, max_dmdt=3.45743 ode_step=1.27518e-12
# step=608, time=2.19832e-10, max_dmdt=3.46627 ode_step=1.27518e-12
# step=609, time=2.21107e-10, max_dmdt=3.61302 ode_step=1.27518e-12
# step=610, time=2.22383e-10, max_dmdt=3.70497 ode_step=1.27518e-12
# step=611, time=2.23658e-10, max_dmdt=3.7466 ode_step=1.27518e-12
# step=612, time=2.24933e-10, max_dmdt=3.74224 ode_step=1.27518e-12
# step=613, time=2.26208e-10, max_dmdt=3.69808 ode_step=1.27518e-12
# step=614, time=2.27483e-10, max_dmdt=3.62179 ode_step=1.27518e-12
# step=615, time=2.28758e-10, max_dmdt=3.51277 ode_step=1.27518e-12
# step=616, time=2.30034e-10, max_dmdt=3.37542 ode_step=1.27518e-12
# step=617, time=2.31309e-10, max_dmdt=3.21399 ode_step=1.27518e-12
# step=618, time=2.32584e-10, max_dmdt=3.03473 ode_step=1.27518e-12
# step=619, time=2.33859e-10, max_dmdt=2.84202 ode_step=1.27518e-12
# step=620, time=2.35134e-10, max_dmdt=2.63665 ode_step=1.27518e-12
# step=621, time=2.3641e-10, max_dmdt=2.42462 ode_step=1.27518e-12
# step=622, time=2.37685e-10, max_dmdt=2.20834 ode_step=1.27518e-12
# step=623, time=2.3896e-10, max_dmdt=1.99348 ode_step=1.27518e-12
# step=624, time=2.40235e-10, max_dmdt=1.78502 ode_step=1.27518e-12
# step=625, time=2.42214e-10, max_dmdt=1.54475 ode_step=1.97936e-12
# step=626, time=2.44194e-10, max_dmdt=1.41154 ode_step=1.97936e-12
# step=627, time=2.46173e-10, max_dmdt=1.39255 ode_step=1.97936e-12
# step=628, time=2.48153e-10, max_dmdt=1.34136 ode_step=1.97936e-12
# step=629, time=2.50132e-10, max_dmdt=1.26307 ode_step=1.97936e-12
# step=630, time=2.52111e-10, max_dmdt=1.16469 ode_step=1.97936e-12
# step=631, time=2.54091e-10, max_dmdt=1.05173 ode_step=1.97936e-12
# step=632, time=2.5607e-10, max_dmdt=0.928918 ode_step=1.97936e-12
# step=633, time=2.58049e-10, max_dmdt=0.801698 ode_step=1.97936e-12
# step=634, time=2.60029e-10, max_dmdt=0.67616 ode_step=1.97936e-12
# step=635, time=2.62008e-10, max_dmdt=0.612437 ode_step=1.97936e-12
# step=636, time=2.63987e-10, max_dmdt=0.653998 ode_step=1.97936e-12
# step=637, time=2.65967e-10, max_dmdt=0.673183 ode_step=1.97936e-12
# step=638, time=2.67946e-10, max_dmdt=0.672911 ode_step=1.97936e-12
# step=639, time=2.69925e-10, max_dmdt=0.655213 ode_step=1.97936e-12
# step=640, time=2.71905e-10, max_dmdt=0.62313 ode_step=1.97936e-12
# step=641, time=2.73884e-10, max_dmdt=0.580274 ode_step=1.97936e-12
# step=642, time=2.75863e-10, max_dmdt=0.52907 ode_step=1.97936e-12
# step=643, time=2.77843e-10, max_dmdt=0.471946 ode_step=1.97936e-12
# step=644, time=2.79822e-10, max_dmdt=0.411928 ode_step=1.97936e-12
# step=645, time=2.81802e-10, max_dmdt=0.352209 ode_step=1.97936e-12
# step=646, time=2.83781e-10, max_dmdt=0.302461 ode_step=1.97936e-12
# step=647, time=2.8576e-10, max_dmdt=0.260555 ode_step=1.97936e-12
# step=648, time=2.8774e-10, max_dmdt=0.255513 ode_step=1.97936e-12
# step=649, time=2.89719e-10, max_dmdt=0.248022 ode_step=1.97936e-12
# step=650, time=2.91698e-10, max_dmdt=0.235194 ode_step=1.97936e-12
# step=651, time=2.93678e-10, max_dmdt=0.218351 ode_step=1.97936e-12
# step=652, time=2.95657e-10, max_dmdt=0.198431 ode_step=1.97936e-12
# step=653, time=2.97636e-10, max_dmdt=0.176353 ode_step=1.97936e-12
# step=654, time=2.99616e-10, max_dmdt=0.153342 ode_step=1.97936e-12
# step=655, time=3.02619e-10, max_dmdt=0.130421 ode_step=3.00282e-12
# step=656, time=3.05621e-10, max_dmdt=0.116239 ode_step=3.00282e-12
# step=657, time=3.08624e-10, max_dmdt=0.12342 ode_step=3.00282e-12
# step=658, time=3.11627e-10, max_dmdt=0.122074 ode_step=3.00282e-12
# step=659, time=3.1463e-10, max_dmdt=0.1142 ode_step=3.00282e-12
# step=660, time=3.17633e-10, max_dmdt=0.101818 ode_step=3.00282e-12
# step=661, time=3.20636e-10, max_dmdt=0.0865662 ode_step=3.00282e-12
# step=662, time=3.23638e-10, max_dmdt=0.0705265 ode_step=3.00282e-12
# step=663, time=3.26641e-10, max_dmdt=0.0566742 ode_step=3.00282e-12
# step=664, time=3.29644e-10, max_dmdt=0.0472276 ode_step=3.00282e-12
# step=665, time=3.32647e-10, max_dmdt=0.0453236 ode_step=3.00282e-12
# step=666, time=3.3565e-10, max_dmdt=0.0413414 ode_step=3.00282e-12
# step=667, time=3.38652e-10, max_dmdt=0.036024 ode_step=3.00282e-12
# step=668, time=3.41655e-10, max_dmdt=0.030342 ode_step=3.00282e-12
# step=669, time=3.44658e-10, max_dmdt=0.0257016 ode_step=3.00282e-12
# step=670, time=3.47661e-10, max_dmdt=0.0212443 ode_step=3.00282e-12
# step=671, time=3.50664e-10, max_dmdt=0.022687 ode_step=3.00282e-12
# step=672, time=3.53667e-10, max_dmdt=0.0225964 ode_step=3.00282e-12
# step=673, time=3.56669e-10, max_dmdt=0.0213406 ode_step=3.00282e-12
# step=674, time=3.59672e-10, max_dmdt=0.0191912 ode_step=3.00282e-12
# step=675, time=3.64202e-10, max_dmdt=0.0157533 ode_step=4.52996e-12
# step=676, time=3.68732e-10, max_dmdt=0.01152 ode_step=4.52996e-12
# step=677, time=3.73262e-10, max_dmdt=0.00870538 ode_step=4.52996e-12

# %% [markdown]
# After the system is relaxed, the magnetisation profile can be plotted.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

m = sim.spin

mx = m[:, 0]
my = m[:, 1]
mz = m[:, 2]

x_array = np.arange(0, L, dx)

plt.figure(figsize=(10,6))
plt.plot(x_array, mx, label='mx')
plt.plot(x_array, my, label='my')
plt.plot(x_array, mz, label='mz')
plt.xlabel('x (nm)')
plt.ylabel('<m>')
plt.xlim([0.4*L, 0.6*L])
plt.ylim([-1, 1])
plt.grid()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-94473078ac69> in <module>()
#       5 m = sim.spin
#       6
# ----> 7 mx = m[:, 0]
#       8 my = m[:, 1]
#       9 mz = m[:, 2]
#
# IndexError: too many indices for array
